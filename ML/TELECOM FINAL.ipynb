# %% [markdown]
# # Телеком

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# **Цель:**
#
# Построить модель, которая сможет максимально точно предсказывать, когда клиент собирается уйти, чтобы компания своевременно смогла предпринять меры.
#
# **План работы:**
#
# *Предобработка данных:*
#
#  - Загрузить данные и провести первичный анализ
#  - Изучить данные, визуализировать признаки
#  - Проверить на мультиколлинеарность, при необходимости удалить некоторые из признаков
#  - Проверить классы на несбалансированность
#
# *Построение модели:*
#  - Построить Pipeline, включить в него кодировку и scaling признаков
#  - Подобрать лучшую модель и гиперпараметры через RandomizedGridSearch
#  - Проверить модели на тествой выборке, анализ подучившейся метрики
#  - Создать матрицу ошибок, проанализировать важность признаков
#
# *Отчет по решению:*
#  - Проанализировать, какие признаки оказались определяющими
#  - Подвести итог, какая модель лучшая и с какими гиперпарамтерами
#  - Предложить, как можно оптимизировать работу

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# !pip install colorama
# !pip install imblearn
# !pip install phik
# Out:
# Requirement already satisfied: colorama in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (0.4.6)
# Requirement already satisfied: imblearn in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: phik in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (0.12.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from phik) (3.7.0)
# Requirement already satisfied: joblib>=0.14.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from phik) (1.1.1)
# Requirement already satisfied: pandas>=0.25.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from phik) (1.5.3)
# Requirement already satisfied: numpy>=1.18.0 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from phik) (1.23.5)
# Requirement already satisfied: scipy>=1.5.2 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from phik) (1.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.3->phik) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from pandas>=0.25.1->phik) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)

# %%
import pandas as pd
from colorama import Fore
import seaborn as sns
import matplotlib.pyplot as plt

import phik
from phik.report import plot_correlation_matrix
from phik import report

# %matplotlib inline



import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector as selector
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler

from sklearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV



import sklearn.metrics
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_auc_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor

# %%
RANDOM_STATE = 240423

# %%
#загружаем данные
try:
    data_personal = pd.read_csv('personal_new.csv')
    data_contract = pd.read_csv('contract_new.csv')
    data_internet = pd.read_csv('internet_new.csv')
    data_phone = pd.read_csv('phone_new.csv')
except:
    data_personal = pd.read_csv('/datasets/personal_new.csv')
    data_contract = pd.read_csv('/datasets/contract_new.csv')
    data_internet = pd.read_csv('/datasets/internet_new.csv')
    data_phone = pd.read_csv('/datasets/phone_new.csv')

# %% [markdown]
# **Personal**

# %% [markdown]
#  - SeniorCitizen - наличие пенсионного статуса
#  - Partner - наличие супруга
#  - Dependents - наличие иждивенцев

# %% [markdown]
# **Contract**

# %% [markdown]
#  - Type - тип оплаты услуг (каждый месяц, раз в месяц)
#  - PaperlessBilling	-  электронный чек или бумажный
#  - PaymentMethod - способ оплаты
#  - MonthlyCharges - клиент ежемесячно платит
#  - TotalCharges - всегог потрачено на услуги

# %% [markdown]
# **Internet**

# %% [markdown]
#  - InternetService - интернет подключение может быть двух типов: через телефонную линию (DSL, от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*)
#
# *Дополнительные услуги*:
#
#  - DeviceProtection - антивирус
#  - OnlineSecurity - блокировка небезопасных сайтов
#  - TechSupport - выделенная линия технической поддержки
#  - OnlineBackup - облачное хранилище файлов для резервного копирования данных
#  - StreamingTV  - стриминговое телевидение
#  - StreamingMovies - каталог фильмов

# %% [markdown]
# **Phone**

# %% [markdown]
#  - MultipleLines - возможность вести звонки на параллельных линиях

# %% [markdown]
# ### Первичный анализ

# %%
datasets = {'Personal': data_personal,
'Contract':data_contract,
'Internet':data_internet,
'Phone':data_phone}

# %%
def general_info(data):
    display(data.head(5))
    print()
    print('Размеры датафрейма:', data.shape)
    print('Количество дубликатов:', data.duplicated().sum())
    print('Количество дубликатов в столбце id:', data['customerID'].duplicated().sum())
    print('Пропуски в данных:') 
    print(data.isna().sum())
    display(data.info())

# %%
for n in datasets.keys():
    print(Fore.BLUE + n)
      
    print(general_info(datasets[n]))
    print()
    print()
# Out:
# Personal
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# Размеры датафрейма: (7043, 5)
# Количество дубликатов: 0
# Количество дубликатов в столбце id: 0
# Пропуски в данных:
# customerID       0
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# None
# None
#
#
# Contract
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01      No        One year               No
# 2  3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01      No        One year               No
# 4  9237-HQITU  2019-09-01      No  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0           Electronic check           29.85        31.04
# 1               Mailed check           56.95      2071.84
# 2               Mailed check           53.85       226.17
# 3  Bank transfer (automatic)           42.30       1960.6
# 4           Electronic check           70.70        353.5
# Размеры датафрейма: (7043, 8)
# Количество дубликатов: 0
# Количество дубликатов в столбце id: 0
# Пропуски в данных:
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# None
# None
#
#
# Internet
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No
# Размеры датафрейма: (5517, 8)
# Количество дубликатов: 0
# Количество дубликатов в столбце id: 0
# Пропуски в данных:
# customerID          0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
# None
# None
#
#
# Phone
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# Размеры датафрейма: (6361, 2)
# Количество дубликатов: 0
# Количество дубликатов в столбце id: 0
# Пропуски в данных:
# customerID       0
# MultipleLines    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# None
# None

# %% [markdown]
# **Мини-вывод:** размеры совпадают только у датафрейма с персональной информацией и о контрактах. У двух остальных датафреймов размеры разные. И это нормально, поскольку у каждого клиента есть контракт, но не каждый клиент пользуется и услугами интернет подключения и услугами телефонии, кто-то использует только что-то одно.

# %% [markdown]
# ### Обьединение датафреймов

# %%
#обьеденим выборки для пользователей с интернетом
data=pd.merge(data_personal,data_contract, on='customerID', how='outer')
data=pd.merge(data,data_internet, on='customerID', how='outer')

data.shape
# Out:
# (7043, 19)

# %%
data.isna().sum()
# Out:
# customerID             0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# dtype: int64

# %% [markdown]
# Пропуски, которые мы видим в данных, это люди, у которых есть конракт с компанией, но которые не используют услуги, связанные с интернетом.

# %%
data['InternetService'] = data['InternetService'].fillna('Not using')
data[data['InternetService'] == 'Not using']['InternetService'].count()
# Out:
# 1526

# %%
data = data.fillna('No')

# %%
data=pd.merge(data,data_phone, on='customerID', how='outer')
data.shape
# Out:
# (7043, 20)

# %%
data.isna().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# BeginDate             0
# EndDate               0
# Type                  0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# MultipleLines       682
# dtype: int64

# %% [markdown]
# 682 человека не используют подключение телефонного аппарата к нескольким линиям одновременно.

# %%
data = data.fillna('No')
#data[data['MultipleLines'] == 'No']['MultipleLines'].count()

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Изучение данных

# %% [markdown]
# Сделаем столбец CustomerID индексом нашего датафрейма

# %%
data = data.set_index('customerID')
data.shape
# Out:
# (7043, 19)

# %% [markdown]
# Добавим столбец с длительностью действия контракта

# %%
#data_closed_contracts = data[data['EndDate'] != 'No']
#data_closed_contracts

# %%
data_closed_contracts = data
data_closed_contracts['End'] = data['EndDate']
data_closed_contracts.loc[data_closed_contracts['End'] == 'No', 'End'] = '2020-02-01'
data_closed_contracts
# Out:
#             gender  SeniorCitizen Partner Dependents   BeginDate EndDate  \
# customerID
# 7590-VHVEG  Female              0     Yes         No  2020-01-01      No
# 5575-GNVDE    Male              0      No         No  2017-04-01      No
# 3668-QPYBK    Male              0      No         No  2019-10-01      No
# 7795-CFOCW    Male              0      No         No  2016-05-01      No
# 9237-HQITU  Female              0      No         No  2019-09-01      No
# ...            ...            ...     ...        ...         ...     ...
# 6840-RESVB    Male              0     Yes        Yes  2018-02-01      No
# 2234-XADUH  Female              0     Yes        Yes  2014-02-01      No
# 4801-JZAZL  Female              0     Yes        Yes  2019-03-01      No
# 8361-LTMKD    Male              1     Yes         No  2019-07-01      No
# 3186-AJIEK    Male              0      No         No  2014-08-01      No
#
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges TotalCharges InternetService OnlineSecurity  \
# customerID
# 7590-VHVEG           29.85        31.04             DSL             No
# 5575-GNVDE           56.95      2071.84             DSL            Yes
# 3668-QPYBK           53.85       226.17             DSL            Yes
# 7795-CFOCW           42.30       1960.6             DSL            Yes
# 9237-HQITU           70.70        353.5     Fiber optic             No
# ...                    ...          ...             ...            ...
# 6840-RESVB           84.80       2035.2             DSL            Yes
# 2234-XADUH          103.20       7430.4     Fiber optic             No
# 4801-JZAZL           29.60        325.6             DSL            Yes
# 8361-LTMKD           74.40        520.8     Fiber optic             No
# 3186-AJIEK          105.65      7251.82     Fiber optic            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 7590-VHVEG          Yes               No          No          No
# 5575-GNVDE           No              Yes          No          No
# 3668-QPYBK          Yes               No          No          No
# 7795-CFOCW           No              Yes         Yes          No
# 9237-HQITU           No               No          No          No
# ...                 ...              ...         ...         ...
# 6840-RESVB           No              Yes         Yes         Yes
# 2234-XADUH          Yes              Yes          No         Yes
# 4801-JZAZL           No               No          No          No
# 8361-LTMKD           No               No          No          No
# 3186-AJIEK           No              Yes         Yes         Yes
#
#            StreamingMovies MultipleLines         End
# customerID
# 7590-VHVEG              No            No  2020-02-01
# 5575-GNVDE              No            No  2020-02-01
# 3668-QPYBK              No            No  2020-02-01
# 7795-CFOCW              No            No  2020-02-01
# 9237-HQITU              No            No  2020-02-01
# ...                    ...           ...         ...
# 6840-RESVB             Yes           Yes  2020-02-01
# 2234-XADUH             Yes           Yes  2020-02-01
# 4801-JZAZL              No            No  2020-02-01
# 8361-LTMKD              No           Yes  2020-02-01
# 3186-AJIEK             Yes            No  2020-02-01
#
# [7043 rows x 20 columns]

# %%
data_closed_contracts['End'] = pd.to_datetime(data_closed_contracts['End'], format='%Y-%m-%d')
data_closed_contracts['BeginDate'] = pd.to_datetime(data_closed_contracts['BeginDate'], format='%Y-%m-%d')

# %%
data_closed_contracts['DurationContract'] = data_closed_contracts['End']-data_closed_contracts['BeginDate']
data_closed_contracts
# Out:
#             gender  SeniorCitizen Partner Dependents  BeginDate EndDate  \
# customerID
# 7590-VHVEG  Female              0     Yes         No 2020-01-01      No
# 5575-GNVDE    Male              0      No         No 2017-04-01      No
# 3668-QPYBK    Male              0      No         No 2019-10-01      No
# 7795-CFOCW    Male              0      No         No 2016-05-01      No
# 9237-HQITU  Female              0      No         No 2019-09-01      No
# ...            ...            ...     ...        ...        ...     ...
# 6840-RESVB    Male              0     Yes        Yes 2018-02-01      No
# 2234-XADUH  Female              0     Yes        Yes 2014-02-01      No
# 4801-JZAZL  Female              0     Yes        Yes 2019-03-01      No
# 8361-LTMKD    Male              1     Yes         No 2019-07-01      No
# 3186-AJIEK    Male              0      No         No 2014-08-01      No
#
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges  ... InternetService OnlineSecurity OnlineBackup  \
# customerID                  ...
# 7590-VHVEG           29.85  ...             DSL             No          Yes
# 5575-GNVDE           56.95  ...             DSL            Yes           No
# 3668-QPYBK           53.85  ...             DSL            Yes          Yes
# 7795-CFOCW           42.30  ...             DSL            Yes           No
# 9237-HQITU           70.70  ...     Fiber optic             No           No
# ...                    ...  ...             ...            ...          ...
# 6840-RESVB           84.80  ...             DSL            Yes           No
# 2234-XADUH          103.20  ...     Fiber optic             No          Yes
# 4801-JZAZL           29.60  ...             DSL            Yes           No
# 8361-LTMKD           74.40  ...     Fiber optic             No           No
# 3186-AJIEK          105.65  ...     Fiber optic            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
# ...                     ...         ...         ...             ...
# 6840-RESVB              Yes         Yes         Yes             Yes
# 2234-XADUH              Yes          No         Yes             Yes
# 4801-JZAZL               No          No          No              No
# 8361-LTMKD               No          No          No              No
# 3186-AJIEK              Yes         Yes         Yes             Yes
#
#            MultipleLines        End DurationContract
# customerID
# 7590-VHVEG            No 2020-02-01          31 days
# 5575-GNVDE            No 2020-02-01        1036 days
# 3668-QPYBK            No 2020-02-01         123 days
# 7795-CFOCW            No 2020-02-01        1371 days
# 9237-HQITU            No 2020-02-01         153 days
# ...                  ...        ...              ...
# 6840-RESVB           Yes 2020-02-01         730 days
# 2234-XADUH           Yes 2020-02-01        2191 days
# 4801-JZAZL            No 2020-02-01         337 days
# 8361-LTMKD           Yes 2020-02-01         215 days
# 3186-AJIEK            No 2020-02-01        2010 days
#
# [7043 rows x 21 columns]

# %%
data['BeginDate'] = pd.to_datetime(data['BeginDate'], format='%Y-%m-%d')

# %%
data_closed_contracts = data_closed_contracts[['BeginDate', 'End', 'DurationContract']]
data_closed_contracts
# Out:
#             BeginDate        End DurationContract
# customerID
# 7590-VHVEG 2020-01-01 2020-02-01          31 days
# 5575-GNVDE 2017-04-01 2020-02-01        1036 days
# 3668-QPYBK 2019-10-01 2020-02-01         123 days
# 7795-CFOCW 2016-05-01 2020-02-01        1371 days
# 9237-HQITU 2019-09-01 2020-02-01         153 days
# ...               ...        ...              ...
# 6840-RESVB 2018-02-01 2020-02-01         730 days
# 2234-XADUH 2014-02-01 2020-02-01        2191 days
# 4801-JZAZL 2019-03-01 2020-02-01         337 days
# 8361-LTMKD 2019-07-01 2020-02-01         215 days
# 3186-AJIEK 2014-08-01 2020-02-01        2010 days
#
# [7043 rows x 3 columns]

# %%
data=pd.merge(data,data_closed_contracts, on='customerID', how='outer')
data
# Out:
#             gender  SeniorCitizen Partner Dependents BeginDate_x EndDate  \
# customerID
# 7590-VHVEG  Female              0     Yes         No  2020-01-01      No
# 5575-GNVDE    Male              0      No         No  2017-04-01      No
# 3668-QPYBK    Male              0      No         No  2019-10-01      No
# 7795-CFOCW    Male              0      No         No  2016-05-01      No
# 9237-HQITU  Female              0      No         No  2019-09-01      No
# ...            ...            ...     ...        ...         ...     ...
# 6840-RESVB    Male              0     Yes        Yes  2018-02-01      No
# 2234-XADUH  Female              0     Yes        Yes  2014-02-01      No
# 4801-JZAZL  Female              0     Yes        Yes  2019-03-01      No
# 8361-LTMKD    Male              1     Yes         No  2019-07-01      No
# 3186-AJIEK    Male              0      No         No  2014-08-01      No
#
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges  ... DeviceProtection TechSupport StreamingTV  \
# customerID                  ...
# 7590-VHVEG           29.85  ...               No          No          No
# 5575-GNVDE           56.95  ...              Yes          No          No
# 3668-QPYBK           53.85  ...               No          No          No
# 7795-CFOCW           42.30  ...              Yes         Yes          No
# 9237-HQITU           70.70  ...               No          No          No
# ...                    ...  ...              ...         ...         ...
# 6840-RESVB           84.80  ...              Yes         Yes         Yes
# 2234-XADUH          103.20  ...              Yes          No         Yes
# 4801-JZAZL           29.60  ...               No          No          No
# 8361-LTMKD           74.40  ...               No          No          No
# 3186-AJIEK          105.65  ...              Yes         Yes         Yes
#
#            StreamingMovies MultipleLines      End_x DurationContract_x  \
# customerID
# 7590-VHVEG              No            No 2020-02-01            31 days
# 5575-GNVDE              No            No 2020-02-01          1036 days
# 3668-QPYBK              No            No 2020-02-01           123 days
# 7795-CFOCW              No            No 2020-02-01          1371 days
# 9237-HQITU              No            No 2020-02-01           153 days
# ...                    ...           ...        ...                ...
# 6840-RESVB             Yes           Yes 2020-02-01           730 days
# 2234-XADUH             Yes           Yes 2020-02-01          2191 days
# 4801-JZAZL              No            No 2020-02-01           337 days
# 8361-LTMKD              No           Yes 2020-02-01           215 days
# 3186-AJIEK             Yes            No 2020-02-01          2010 days
#
#            BeginDate_y      End_y DurationContract_y
# customerID
# 7590-VHVEG  2020-01-01 2020-02-01            31 days
# 5575-GNVDE  2017-04-01 2020-02-01          1036 days
# 3668-QPYBK  2019-10-01 2020-02-01           123 days
# 7795-CFOCW  2016-05-01 2020-02-01          1371 days
# 9237-HQITU  2019-09-01 2020-02-01           153 days
# ...                ...        ...                ...
# 6840-RESVB  2018-02-01 2020-02-01           730 days
# 2234-XADUH  2014-02-01 2020-02-01          2191 days
# 4801-JZAZL  2019-03-01 2020-02-01           337 days
# 8361-LTMKD  2019-07-01 2020-02-01           215 days
# 3186-AJIEK  2014-08-01 2020-02-01          2010 days
#
# [7043 rows x 24 columns]

# %%
data = data.drop(columns=['BeginDate_y','End_y', 'DurationContract_y','End_x'])

# %%
#data['DurationContract'] = data['DurationContract'].fillna('Not ended')

# %%
data = data[data['TotalCharges'] != ' ']

# %%
data['DurationContract_x'] = data['DurationContract_x'].astype('str')

# %%
data['DurationContract_x'] = data['DurationContract_x'].map(lambda x: x.rstrip('days'))

# %%
data['TotalCharges'] = data['TotalCharges'].astype('float64')

data['DurationContract_x'] = data['DurationContract_x'].astype('int')
data['SeniorCitizen'] = data['SeniorCitizen'].astype('str')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gender              7032 non-null   object
#  1   SeniorCitizen       7032 non-null   object
#  2   Partner             7032 non-null   object
#  3   Dependents          7032 non-null   object
#  4   BeginDate_x         7032 non-null   datetime64[ns]
#  5   EndDate             7032 non-null   object
#  6   Type                7032 non-null   object
#  7   PaperlessBilling    7032 non-null   object
#  8   PaymentMethod       7032 non-null   object
#  9   MonthlyCharges      7032 non-null   float64
#  10  TotalCharges        7032 non-null   float64
#  11  InternetService     7032 non-null   object
#  12  OnlineSecurity      7032 non-null   object
#  13  OnlineBackup        7032 non-null   object
#  14  DeviceProtection    7032 non-null   object
#  15  TechSupport         7032 non-null   object
#  16  StreamingTV         7032 non-null   object
#  17  StreamingMovies     7032 non-null   object
#  18  MultipleLines       7032 non-null   object
#  19  DurationContract_x  7032 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 1.1+ MB

# %% [markdown]
# Избавимся от выбросов

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data  = data.loc[data['TotalCharges'] <= 7500]
data.shape
# Out:
# (6851, 20)

# %%
phik_overview = data.phik_matrix()
phik_overview.round(2)
# Out:
# interval columns not set, guessing: ['MonthlyCharges', 'TotalCharges', 'DurationContract_x']
#                     gender  SeniorCitizen  Partner  Dependents  BeginDate_x  \
# gender                1.00           0.00     0.00        0.00         0.02
# SeniorCitizen         0.00           1.00     0.02        0.32         0.05
# Partner               0.00           0.02     1.00        0.66         0.46
# Dependents            0.00           0.32     0.66        1.00         0.20
# BeginDate_x           0.02           0.05     0.46        0.20         1.00
# EndDate               0.02           0.09     0.19        0.06         0.56
# Type                  0.00           0.09     0.17        0.15         0.77
# PaperlessBilling      0.00           0.24     0.03        0.17         0.09
# PaymentMethod         0.01           0.30     0.23        0.22         0.45
# MonthlyCharges        0.00           0.31     0.17        0.19         0.37
# TotalCharges          0.03           0.14     0.37        0.10         0.77
# InternetService       0.00           0.16     0.01        0.11         0.23
# OnlineSecurity        0.02           0.05     0.20        0.11         0.37
# OnlineBackup          0.01           0.10     0.20        0.02         0.41
# DeviceProtection      0.00           0.09     0.21        0.00         0.42
# TechSupport           0.00           0.10     0.16        0.09         0.36
# StreamingTV           0.00           0.16     0.17        0.03         0.32
# StreamingMovies       0.00           0.19     0.16        0.07         0.33
# MultipleLines         0.00           0.22     0.20        0.04         0.40
# DurationContract_x    0.00           0.07     0.44        0.20         0.98
#
#                     EndDate  Type  PaperlessBilling  PaymentMethod  \
# gender                 0.02  0.00              0.00           0.01
# SeniorCitizen          0.09  0.09              0.24           0.30
# Partner                0.19  0.17              0.03           0.23
# Dependents             0.06  0.15              0.17           0.22
# BeginDate_x            0.56  0.77              0.09           0.45
# EndDate                1.00  0.31              0.07           0.18
# Type                   0.31  1.00              0.12           0.28
# PaperlessBilling       0.07  0.12              1.00           0.37
# PaymentMethod          0.18  0.28              0.37           1.00
# MonthlyCharges         0.24  0.36              0.47           0.39
# TotalCharges           0.24  0.44              0.20           0.33
# InternetService        0.14  0.55              0.23           0.33
# OnlineSecurity         0.15  0.14              0.00           0.24
# OnlineBackup           0.22  0.08              0.19           0.26
# DeviceProtection       0.22  0.12              0.15           0.29
# TechSupport            0.13  0.17              0.04           0.25
# StreamingTV            0.18  0.05              0.34           0.37
# StreamingMovies        0.20  0.05              0.32           0.37
# MultipleLines          0.23  0.05              0.24           0.33
# DurationContract_x     0.39  0.62              0.06           0.34
#
#                     MonthlyCharges  TotalCharges  InternetService  \
# gender                        0.00          0.03             0.00
# SeniorCitizen                 0.31          0.14             0.16
# Partner                       0.17          0.37             0.01
# Dependents                    0.19          0.10             0.11
# BeginDate_x                   0.37          0.77             0.23
# EndDate                       0.24          0.24             0.14
# Type                          0.36          0.44             0.55
# PaperlessBilling              0.47          0.20             0.23
# PaymentMethod                 0.39          0.33             0.33
# MonthlyCharges                1.00          0.62             0.92
# TotalCharges                  0.62          1.00             0.46
# InternetService               0.92          0.46             1.00
# OnlineSecurity                0.53          0.50             0.25
# OnlineBackup                  0.60          0.59             0.23
# DeviceProtection              0.63          0.61             0.23
# TechSupport                   0.54          0.52             0.25
# StreamingTV                   0.82          0.61             0.26
# StreamingMovies               0.82          0.61             0.26
# MultipleLines                 0.65          0.55             0.21
# DurationContract_x            0.33          0.84             0.14
#
#                     OnlineSecurity  OnlineBackup  DeviceProtection  \
# gender                        0.02          0.01              0.00
# SeniorCitizen                 0.05          0.10              0.09
# Partner                       0.20          0.20              0.21
# Dependents                    0.11          0.02              0.00
# BeginDate_x                   0.37          0.41              0.42
# EndDate                       0.15          0.22              0.22
# Type                          0.14          0.08              0.12
# PaperlessBilling              0.00          0.19              0.15
# PaymentMethod                 0.24          0.26              0.29
# MonthlyCharges                0.53          0.60              0.63
# TotalCharges                  0.50          0.59              0.61
# InternetService               0.25          0.23              0.23
# OnlineSecurity                1.00          0.41              0.39
# OnlineBackup                  0.41          1.00              0.42
# DeviceProtection              0.39          0.42              1.00
# TechSupport                   0.51          0.41              0.47
# StreamingTV                   0.24          0.39              0.54
# StreamingMovies               0.26          0.38              0.56
# MultipleLines                 0.12          0.28              0.27
# DurationContract_x            0.36          0.37              0.38
#
#                     TechSupport  StreamingTV  StreamingMovies  MultipleLines  \
# gender                     0.00         0.00             0.00           0.00
# SeniorCitizen              0.10         0.16             0.19           0.22
# Partner                    0.16         0.17             0.16           0.20
# Dependents                 0.09         0.03             0.07           0.04
# BeginDate_x                0.36         0.32             0.33           0.40
# EndDate                    0.13         0.18             0.20           0.23
# Type                       0.17         0.05             0.05           0.05
# PaperlessBilling           0.04         0.34             0.32           0.24
# PaymentMethod              0.25         0.37             0.37           0.33
# MonthlyCharges             0.54         0.82             0.82           0.65
# TotalCharges               0.52         0.61             0.61           0.55
# InternetService            0.25         0.26             0.26           0.21
# OnlineSecurity             0.51         0.24             0.26           0.12
# OnlineBackup               0.41         0.39             0.38           0.28
# DeviceProtection           0.47         0.54             0.56           0.27
# TechSupport                1.00         0.39             0.39           0.12
# StreamingTV                0.39         1.00             0.72           0.36
# StreamingMovies            0.39         0.72             1.00           0.36
# MultipleLines              0.12         0.36             0.36           1.00
# DurationContract_x         0.36         0.29             0.29           0.36
#
#                     DurationContract_x
# gender                            0.00
# SeniorCitizen                     0.07
# Partner                           0.44
# Dependents                        0.20
# BeginDate_x                       0.98
# EndDate                           0.39
# Type                              0.62
# PaperlessBilling                  0.06
# PaymentMethod                     0.34
# MonthlyCharges                    0.33
# TotalCharges                      0.84
# InternetService                   0.14
# OnlineSecurity                    0.36
# OnlineBackup                      0.37
# DeviceProtection                  0.38
# TechSupport                       0.36
# StreamingTV                       0.29
# StreamingMovies                   0.29
# MultipleLines                     0.36
# DurationContract_x                1.00

# %%
# %matplotlib inline

# %%
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Blues", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(15,20))
plt.tight_layout()

# %% [markdown]
# У нас есть некоторые признаки, значение которых сильно зависит от величины других. Это явление мультиколлинеарности и от него лучше избавиться, лишние признаки не нужны модели. Лишняя информация может повлиять в негативном ключе на качество предсказаний.
#
# - В первую очередь, мы можем удалить столбец с датой начала контракта, поскольку у нас уже есть DurationContract, следовательно, когда именно началось действи еокнтракта уже не так важно.
#
#
# - Вызывает подозрения признак Gender, тк он не связан абсолютно ни с одним другим признаком. Сложно представить, что пол клиента может влиять на пользование услугами и желание разорвать контракт. Поэтому удаление этого признака не должно повлиять на работу модели, он не несет в себе ценнной информации.

# %%
significance_overview = data.significance_matrix()
significance_overview.round(2)
# Out:
# interval columns not set, guessing: ['MonthlyCharges', 'TotalCharges', 'DurationContract_x']
#                     gender  SeniorCitizen  Partner  Dependents  BeginDate_x  \
# gender               97.24          -1.41    -0.91       -0.05         0.23
# SeniorCitizen        -1.41          77.56     0.89       19.05         1.23
# Partner              -0.91           0.89    97.15       38.55        29.06
# Dependents           -0.05          19.05    38.55       91.05         9.69
# BeginDate_x           0.23           1.23    29.06        9.69       195.65
# EndDate               0.26           1.88     9.54        1.20        11.16
# Type                 -1.02          12.57    23.47       19.82        56.88
# PaperlessBilling      0.57          13.33     1.43        9.06         2.50
# PaymentMethod         0.35          16.65    12.53       12.04        27.97
# MonthlyCharges        0.06          19.90     9.73       10.74        21.09
# TotalCharges          0.69           7.93    22.99        5.04        81.21
# InternetService      -0.45          23.07     0.55       15.40         7.50
# OnlineSecurity        1.07           2.84    10.62        5.81        21.94
# OnlineBackup          0.64           5.15    10.37        1.29        24.89
# DeviceProtection     -1.36           4.78    11.13        0.07        25.86
# TechSupport           0.00           5.39     8.58        4.73        21.37
# StreamingTV          -0.34           8.45     8.80        1.43        18.77
# StreamingMovies       0.17           9.71     8.29        3.50        19.62
# MultipleLines        -0.17          11.70    10.66        1.98        24.27
# DurationContract_x   -0.61           3.16    27.71       11.77       139.13
#
#                     EndDate    Type  PaperlessBilling  PaymentMethod  \
# gender                 0.26   -1.02              0.57           0.35
# SeniorCitizen          1.88   12.57             13.33          16.65
# Partner                9.54   23.47              1.43          12.53
# Dependents             1.20   19.82              9.06          12.04
# BeginDate_x           11.16   56.88              2.50          27.97
# EndDate              105.20   11.83              2.08           7.37
# Type                  11.83  116.01             15.87          31.83
# PaperlessBilling       2.08   15.87             96.15          20.41
# PaymentMethod          7.37   31.83             20.41         136.48
# MonthlyCharges         6.65   25.53             29.33          35.08
# TotalCharges           9.30   33.77             11.52          27.99
# InternetService        3.63   27.90             31.52          37.69
# OnlineSecurity         5.28   18.84              0.54          12.99
# OnlineBackup          10.87   11.06              9.88          14.49
# DeviceProtection      10.42   16.22              7.80          16.07
# TechSupport            4.25   22.32              2.09          13.24
# StreamingTV            8.38    6.51             18.23          21.19
# StreamingMovies        9.24    6.95             17.24          21.24
# MultipleLines         11.84    6.06             13.12          18.55
# DurationContract_x    20.19   54.77              2.62          29.23
#
#                     MonthlyCharges  TotalCharges  InternetService  \
# gender                        0.06          0.69            -0.45
# SeniorCitizen                19.90          7.93            23.07
# Partner                       9.73         22.99             0.55
# Dependents                   10.74          5.04            15.40
# BeginDate_x                  21.09         81.21             7.50
# EndDate                       6.65          9.30             3.63
# Type                         25.53         33.77            27.90
# PaperlessBilling             29.33         11.52            31.52
# PaymentMethod                35.08         27.99            37.69
# MonthlyCharges              169.02         58.43           104.75
# TotalCharges                 58.43        160.23            41.03
# InternetService             104.75         41.03           120.61
# OnlineSecurity               37.73         31.13            38.14
# OnlineBackup                 43.15         37.38            37.56
# DeviceProtection             45.19         38.76            37.55
# TechSupport                  38.59         32.36            38.03
# StreamingTV                  59.26         38.86            41.61
# StreamingMovies              59.14         38.74            41.72
# MultipleLines                44.26         35.43            29.12
# DurationContract_x           23.70         97.90             8.14
#
#                     OnlineSecurity  OnlineBackup  DeviceProtection  \
# gender                        1.07          0.64             -1.36
# SeniorCitizen                 2.84          5.15              4.78
# Partner                      10.62         10.37             11.13
# Dependents                    5.81          1.29              0.07
# BeginDate_x                  21.94         24.89             25.86
# EndDate                       5.28         10.87             10.42
# Type                         18.84         11.06             16.22
# PaperlessBilling              0.54          9.88              7.80
# PaymentMethod                12.99         14.49             16.07
# MonthlyCharges               37.73         43.15             45.19
# TotalCharges                 31.13         37.38             38.76
# InternetService              38.14         37.56             37.55
# OnlineSecurity               89.57         21.85             20.70
# OnlineBackup                 21.85         93.02             22.79
# DeviceProtection             20.70         22.79             92.91
# TechSupport                  27.44         22.11             25.34
# StreamingTV                  12.46         20.98             30.12
# StreamingMovies              13.55         20.40             31.29
# MultipleLines                 6.37         14.64             14.33
# DurationContract_x           22.27         23.39             24.04
#
#                     TechSupport  StreamingTV  StreamingMovies  MultipleLines  \
# gender                     0.00        -0.34             0.17          -0.17
# SeniorCitizen              5.39         8.45             9.71          11.70
# Partner                    8.58         8.80             8.29          10.66
# Dependents                 4.73         1.43             3.50           1.98
# BeginDate_x               21.37        18.77            19.62          24.27
# EndDate                    4.25         8.38             9.24          11.84
# Type                      22.32         6.51             6.95           6.06
# PaperlessBilling           2.09        18.23            17.24          13.12
# PaymentMethod             13.24        21.19            21.24          18.55
# MonthlyCharges            38.59        59.26            59.14          44.26
# TotalCharges              32.36        38.86            38.74          35.43
# InternetService           38.03        41.61            41.72          29.12
# OnlineSecurity            27.44        12.46            13.55           6.37
# OnlineBackup              22.11        20.98            20.40          14.64
# DeviceProtection          25.34        30.12            31.29          14.33
# TechSupport               89.70        20.83            21.10           6.10
# StreamingTV               20.83        94.76            42.85          19.28
# StreamingMovies           21.10        42.85            94.92          19.40
# MultipleLines              6.10        19.28            19.40          96.05
# DurationContract_x        22.34        18.09            17.98          22.49
#
#                     DurationContract_x
# gender                           -0.61
# SeniorCitizen                     3.16
# Partner                          27.71
# Dependents                       11.77
# BeginDate_x                     139.13
# EndDate                          20.19
# Type                             54.77
# PaperlessBilling                  2.62
# PaymentMethod                    29.23
# MonthlyCharges                   23.70
# TotalCharges                     97.90
# InternetService                   8.14
# OnlineSecurity                   22.27
# OnlineBackup                     23.39
# DeviceProtection                 24.04
# TechSupport                      22.34
# StreamingTV                      18.09
# StreamingMovies                  17.98
# MultipleLines                    22.49
# DurationContract_x              171.22

# %%
plot_correlation_matrix(significance_overview.fillna(0).values, 
                        x_labels=significance_overview.columns, 
                        y_labels=significance_overview.index, 
                        vmin=-5, vmax=5, title="Significance of the coefficients", 
                        usetex=False, fontsize_factor=1.5, figsize=(23, 25))
plt.tight_layout()

# %% [markdown]
# Еще раз можно убедиться по графику ваджности признаков, что пол клиента не является ценной информацией.

# %%
data = data.drop(columns=['BeginDate_x', 'gender'])

# %%
data.shape
# Out:
# (6851, 18)

# %% [markdown]
# Создадим столбец с единичками (если дата окончания указана,т.е. если контракт закончился) и нулями (если конракт еще действует)

# %%
data['EndDate_bool'] = 0
data.loc[data['EndDate'] != 'No','EndDate_bool'] = 1
data.head(50)
# Out:
#            SeniorCitizen Partner Dependents     EndDate            Type  \
# customerID
# 7590-VHVEG             0     Yes         No          No  Month-to-month
# 5575-GNVDE             0      No         No          No        One year
# 3668-QPYBK             0      No         No          No  Month-to-month
# 7795-CFOCW             0      No         No          No        One year
# 9237-HQITU             0      No         No          No  Month-to-month
# 9305-CDSKC             0      No         No          No  Month-to-month
# 1452-KIOVK             0      No        Yes          No  Month-to-month
# 6713-OKOMC             0      No         No          No  Month-to-month
# 7892-POOKP             0     Yes         No          No  Month-to-month
# 6388-TABGU             0      No        Yes  2017-05-01        One year
# 9763-GRSKD             0     Yes        Yes          No  Month-to-month
# 7469-LKBCI             0      No         No          No        Two year
# 8091-TTVAX             0     Yes         No          No        One year
# 0280-XJGEX             0      No         No          No  Month-to-month
# 5129-JLPIS             0      No         No          No  Month-to-month
# 3655-SNQYZ             0     Yes        Yes  2016-03-01        Two year
# 8191-XWSZG             0      No         No          No        One year
# 4190-MFLUW             0     Yes        Yes          No  Month-to-month
# 4183-MYFRB             0      No         No          No  Month-to-month
# 8779-QRDMV             1      No         No          No  Month-to-month
# 1680-VDCWW             0     Yes         No          No        One year
# 1066-JKSGK             0      No         No          No  Month-to-month
# 3638-WEABW             0     Yes         No          No        Two year
# 6322-HRPFA             0     Yes        Yes          No  Month-to-month
# 6865-JZNKO             0      No         No  2018-09-01  Month-to-month
# 6467-CHFZW             0     Yes        Yes          No  Month-to-month
# 8665-UTDHZ             0     Yes        Yes          No  Month-to-month
# 5248-YGIJN             0     Yes         No          No        Two year
# 8773-HHUOZ             0      No        Yes          No  Month-to-month
# 3841-NFECX             1     Yes         No  2018-11-01        Two year
# 4929-XIHVW             1     Yes         No          No  Month-to-month
# 6827-IEAUQ             0     Yes        Yes          No        One year
# 7310-EGVHZ             0      No         No          No  Month-to-month
# 3413-BMNZE             1      No         No          No  Month-to-month
# 6234-RAAPL             0     Yes        Yes  2018-12-01        Two year
# 6047-YHPVI             0      No         No          No  Month-to-month
# 6572-ADKRS             0      No         No          No  Month-to-month
# 5380-WJKOV             0      No         No          No  Month-to-month
# 8168-UQWWF             0      No         No          No  Month-to-month
# 8865-TNMNX             0     Yes        Yes          No        One year
# 9489-DEDVP             0     Yes        Yes  2019-08-01        Two year
# 9867-JCZSP             0     Yes        Yes          No        One year
# 4671-VJLCL             0      No         No          No        Two year
# 4080-IIARD             0     Yes         No          No  Month-to-month
# 3714-NTNFO             0      No         No          No  Month-to-month
# 5948-UJZLF             0      No         No          No  Month-to-month
# 7760-OYPDY             0      No         No          No  Month-to-month
# 7639-LIAYI             0      No         No          No        Two year
# 2954-PIBKO             0     Yes        Yes          No        Two year
# 8012-SOUDQ             1      No         No          No  Month-to-month
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check           53.85
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check           20.65
# 4190-MFLUW               No    Credit card (automatic)           55.20
# 4183-MYFRB              Yes           Electronic check           90.05
# 8779-QRDMV              Yes           Electronic check           39.65
# 1680-VDCWW               No  Bank transfer (automatic)           19.80
# 1066-JKSGK               No               Mailed check           20.15
# 3638-WEABW              Yes    Credit card (automatic)           59.90
# 6322-HRPFA               No    Credit card (automatic)           59.60
# 6865-JZNKO              Yes  Bank transfer (automatic)           55.30
# 6467-CHFZW              Yes           Electronic check           99.35
# 8665-UTDHZ               No           Electronic check           30.20
# 5248-YGIJN              Yes    Credit card (automatic)           90.25
# 8773-HHUOZ              Yes               Mailed check           64.70
# 3841-NFECX              Yes    Credit card (automatic)           96.35
# 4929-XIHVW              Yes    Credit card (automatic)           95.50
# 6827-IEAUQ               No               Mailed check           66.15
# 7310-EGVHZ               No  Bank transfer (automatic)           20.20
# 3413-BMNZE               No  Bank transfer (automatic)           45.25
# 6234-RAAPL               No  Bank transfer (automatic)           99.90
# 6047-YHPVI              Yes           Electronic check           69.70
# 6572-ADKRS              Yes    Credit card (automatic)           74.80
# 5380-WJKOV              Yes           Electronic check          106.35
# 8168-UQWWF              Yes  Bank transfer (automatic)           97.85
# 8865-TNMNX               No               Mailed check           49.55
# 9489-DEDVP              Yes    Credit card (automatic)           69.20
# 9867-JCZSP               No               Mailed check           20.75
# 4671-VJLCL              Yes    Credit card (automatic)           79.85
# 4080-IIARD              Yes           Electronic check           76.20
# 3714-NTNFO              Yes           Electronic check           84.50
# 5948-UJZLF               No               Mailed check           49.25
# 7760-OYPDY              Yes           Electronic check           80.65
# 7639-LIAYI              Yes    Credit card (automatic)           79.75
# 2954-PIBKO              Yes    Credit card (automatic)           64.15
# 8012-SOUDQ              Yes           Electronic check           90.25
#
#             TotalCharges InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG         31.04             DSL             No          Yes
# 5575-GNVDE       2071.84             DSL            Yes           No
# 3668-QPYBK        226.17             DSL            Yes          Yes
# 7795-CFOCW       1960.60             DSL            Yes           No
# 9237-HQITU        353.50     Fiber optic             No           No
# 9305-CDSKC       1150.96     Fiber optic             No           No
# 1452-KIOVK       2058.21     Fiber optic             No          Yes
# 6713-OKOMC        300.48             DSL            Yes           No
# 7892-POOKP       3573.68     Fiber optic             No           No
# 6388-TABGU       1628.35             DSL            Yes          Yes
# 9763-GRSKD        649.35             DSL            Yes           No
# 7469-LKBCI        312.30       Not using             No           No
# 8091-TTVAX       6111.31     Fiber optic             No           No
# 0280-XJGEX       5496.10     Fiber optic             No          Yes
# 5129-JLPIS       2637.50     Fiber optic            Yes           No
# 3655-SNQYZ       2491.50     Fiber optic            Yes          Yes
# 8191-XWSZG       1106.01       Not using             No           No
# 4190-MFLUW        789.36             DSL             No           No
# 4183-MYFRB       1891.05     Fiber optic             No          Yes
# 8779-QRDMV        118.95             DSL             No           No
# 1680-VDCWW        237.60       Not using             No           No
# 1066-JKSGK         61.05       Not using             No           No
# 3638-WEABW       3821.62             DSL             No          Yes
# 6322-HRPFA       3212.44             DSL            Yes          Yes
# 6865-JZNKO        726.09             DSL            Yes          Yes
# 6467-CHFZW       5215.88     Fiber optic             No          Yes
# 8665-UTDHZ         96.04             DSL             No          Yes
# 5248-YGIJN       6498.00             DSL            Yes          Yes
# 8773-HHUOZ       1294.00             DSL             No           No
# 3841-NFECX       5395.60     Fiber optic            Yes          Yes
# 4929-XIHVW        194.82     Fiber optic             No           No
# 6827-IEAUQ       1928.93             DSL            Yes          Yes
# 7310-EGVHZ         22.22       Not using             No           No
# 3413-BMNZE         45.25             DSL             No           No
# 6234-RAAPL       5794.20     Fiber optic            Yes          Yes
# 6047-YHPVI        557.60     Fiber optic             No           No
# 6572-ADKRS       3440.80     Fiber optic             No           No
# 5380-WJKOV       4211.46     Fiber optic             No          Yes
# 8168-UQWWF       1369.90     Fiber optic             No           No
# 8865-TNMNX        495.50             DSL             No          Yes
# 9489-DEDVP       4428.80             DSL            Yes          Yes
# 9867-JCZSP        352.75       Not using             No           No
# 4671-VJLCL       5030.55             DSL            Yes          Yes
# 4080-IIARD        990.60             DSL            Yes          Yes
# 3714-NTNFO       4140.50     Fiber optic             No           No
# 5948-UJZLF         98.50             DSL             No          Yes
# 7760-OYPDY        241.95     Fiber optic             No           No
# 7639-LIAYI       4395.82             DSL            Yes           No
# 2954-PIBKO       4780.46             DSL            Yes           No
# 8012-SOUDQ       3880.75     Fiber optic             No          Yes
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
# 9305-CDSKC              Yes          No         Yes             Yes
# 1452-KIOVK               No          No         Yes              No
# 6713-OKOMC               No          No          No              No
# 7892-POOKP              Yes         Yes         Yes             Yes
# 6388-TABGU               No          No          No              No
# 9763-GRSKD               No          No          No              No
# 7469-LKBCI               No          No          No              No
# 8091-TTVAX              Yes          No         Yes             Yes
# 0280-XJGEX              Yes          No         Yes             Yes
# 5129-JLPIS              Yes         Yes         Yes             Yes
# 3655-SNQYZ              Yes         Yes         Yes             Yes
# 8191-XWSZG               No          No          No              No
# 4190-MFLUW              Yes         Yes          No              No
# 4183-MYFRB              Yes          No          No             Yes
# 8779-QRDMV              Yes          No          No             Yes
# 1680-VDCWW               No          No          No              No
# 1066-JKSGK               No          No          No              No
# 3638-WEABW               No         Yes          No              No
# 6322-HRPFA               No         Yes          No              No
# 6865-JZNKO               No          No          No              No
# 6467-CHFZW               No          No         Yes             Yes
# 8665-UTDHZ               No          No          No              No
# 5248-YGIJN              Yes         Yes         Yes             Yes
# 8773-HHUOZ               No          No         Yes             Yes
# 3841-NFECX              Yes         Yes          No              No
# 4929-XIHVW              Yes          No         Yes             Yes
# 6827-IEAUQ              Yes         Yes          No              No
# 7310-EGVHZ               No          No          No              No
# 3413-BMNZE               No          No          No              No
# 6234-RAAPL               No         Yes         Yes              No
# 6047-YHPVI               No          No          No              No
# 6572-ADKRS              Yes          No          No              No
# 5380-WJKOV              Yes          No         Yes             Yes
# 8168-UQWWF              Yes          No         Yes             Yes
# 8865-TNMNX               No          No          No              No
# 9489-DEDVP               No          No         Yes              No
# 9867-JCZSP               No          No          No              No
# 4671-VJLCL              Yes         Yes         Yes              No
# 4080-IIARD               No         Yes         Yes              No
# 3714-NTNFO               No          No          No             Yes
# 5948-UJZLF               No          No          No              No
# 7760-OYPDY               No          No         Yes              No
# 7639-LIAYI               No         Yes         Yes             Yes
# 2954-PIBKO              Yes         Yes          No              No
# 8012-SOUDQ               No          No         Yes              No
#
#            MultipleLines  DurationContract_x  EndDate_bool
# customerID
# 7590-VHVEG            No                  31             0
# 5575-GNVDE            No                1036             0
# 3668-QPYBK            No                 123             0
# 7795-CFOCW            No                1371             0
# 9237-HQITU            No                 153             0
# 9305-CDSKC           Yes                 337             0
# 1452-KIOVK           Yes                 671             0
# 6713-OKOMC            No                 306             0
# 7892-POOKP           Yes                 945             0
# 6388-TABGU            No                 882             1
# 9763-GRSKD            No                 396             0
# 7469-LKBCI            No                 488             0
# 8091-TTVAX           Yes                1767             0
# 0280-XJGEX           Yes                1614             0
# 5129-JLPIS            No                 761             0
# 3655-SNQYZ           Yes                 670             1
# 8191-XWSZG            No                1584             0
# 4190-MFLUW            No                 396             0
# 4183-MYFRB            No                 641             0
# 8779-QRDMV            No                  92             0
# 1680-VDCWW            No                 365             0
# 1066-JKSGK            No                  92             0
# 3638-WEABW           Yes                1767             0
# 6322-HRPFA            No                1492             0
# 6865-JZNKO            No                 396             1
# 6467-CHFZW           Yes                1523             0
# 8665-UTDHZ            No                  92             0
# 5248-YGIJN           Yes                2191             0
# 8773-HHUOZ            No                 610             0
# 3841-NFECX           Yes                1706             1
# 4929-XIHVW            No                  62             0
# 6827-IEAUQ            No                 822             0
# 7310-EGVHZ            No                  31             0
# 3413-BMNZE            No                  31             0
# 6234-RAAPL           Yes                1764             1
# 6047-YHPVI            No                 245             0
# 6572-ADKRS            No                1401             0
# 5380-WJKOV           Yes                1095             0
# 8168-UQWWF           Yes                 427             0
# 8865-TNMNX            No                 306             0
# 9489-DEDVP           Yes                1948             1
# 9867-JCZSP            No                 518             0
# 4671-VJLCL           Yes                1918             0
# 4080-IIARD           Yes                 396             0
# 3714-NTNFO           Yes                1492             0
# 5948-UJZLF            No                  62             0
# 7760-OYPDY            No                  92             0
# 7639-LIAYI           Yes                1584             0
# 2954-PIBKO           Yes                2102             0
# 8012-SOUDQ           Yes                1310             0

# %%
data = data.drop(columns='EndDate')

# %% [markdown]
# Проверим выборку на дисбаланс

# %%
data['EndDate_bool'].value_counts()
# Out:
# 0    5753
# 1    1098
# Name: EndDate_bool, dtype: int64

# %%
data['EndDate_bool'].hist();
plt.xlabel('EndDate', fontsize=10)
plt.ylabel('Amount', fontsize=10)
plt.title('The contract is opened/closed', fontsize=12)
# Out:
# Text(0.5, 1.0, 'The contract is opened/closed')

# %% [markdown]
# Дисбаланс присутсвует, людей с действующим контрактом гораздо (примерно в пять раз) больше. Мы не будем ничего предпренимать, тк наша метрика не чувствительна к дисбалансу классов.

# %%
def build_graph(column):
    plt.figure(figsize=(10,5))
    sns.histplot(data.loc[data['EndDate_bool'] == 1][column], alpha=0.8, color='green', label='left');
    sns.histplot(data.loc[data['EndDate_bool'] == 0][column], alpha =0.3, color = 'purple', label='stayed');
    plt.legend()
    plt.title(f'{column} as the reason for leaving')

# %%
build_graph('Type')

# %%
build_graph('PaymentMethod')

# %%
build_graph('Dependents')

# %% [markdown]
# **Мини-вывод:**
# - Есть ли у клиента зависящие от него финансово люди, на первый взгляд, не влияет на прекращение контракта. Прослеживается связь между PaymentMethod и уходом киента.
# - Среди ушедших очень мало людей, использовавших Mailed Check, хотя среди продолжающих пользоваться услгами таких людей много.
# - Тип оплаты среди ушедших примерно одинаковый, однако среди оставшихся клиентов сильно преобладает метод 'Month-to-month'

# %% [markdown]
# ## Создание модели

# %%
#data = data.reset_index(inplace=True, drop=True)

# %%
X = data.drop(['EndDate_bool'], axis=1)
y = data['EndDate_bool']
X
# Out:
#            SeniorCitizen Partner Dependents            Type PaperlessBilling  \
# customerID
# 7590-VHVEG             0     Yes         No  Month-to-month              Yes
# 5575-GNVDE             0      No         No        One year               No
# 3668-QPYBK             0      No         No  Month-to-month              Yes
# 7795-CFOCW             0      No         No        One year               No
# 9237-HQITU             0      No         No  Month-to-month              Yes
# ...                  ...     ...        ...             ...              ...
# 6840-RESVB             0     Yes        Yes        One year              Yes
# 2234-XADUH             0     Yes        Yes        One year              Yes
# 4801-JZAZL             0     Yes        Yes  Month-to-month              Yes
# 8361-LTMKD             1     Yes         No  Month-to-month              Yes
# 3186-AJIEK             0      No         No        Two year              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG           Electronic check           29.85         31.04
# 5575-GNVDE               Mailed check           56.95       2071.84
# 3668-QPYBK               Mailed check           53.85        226.17
# 7795-CFOCW  Bank transfer (automatic)           42.30       1960.60
# 9237-HQITU           Electronic check           70.70        353.50
# ...                               ...             ...           ...
# 6840-RESVB               Mailed check           84.80       2035.20
# 2234-XADUH    Credit card (automatic)          103.20       7430.40
# 4801-JZAZL           Electronic check           29.60        325.60
# 8361-LTMKD               Mailed check           74.40        520.80
# 3186-AJIEK  Bank transfer (automatic)          105.65       7251.82
#
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 7590-VHVEG             DSL             No          Yes               No
# 5575-GNVDE             DSL            Yes           No              Yes
# 3668-QPYBK             DSL            Yes          Yes               No
# 7795-CFOCW             DSL            Yes           No              Yes
# 9237-HQITU     Fiber optic             No           No               No
# ...                    ...            ...          ...              ...
# 6840-RESVB             DSL            Yes           No              Yes
# 2234-XADUH     Fiber optic             No          Yes              Yes
# 4801-JZAZL             DSL            Yes           No               No
# 8361-LTMKD     Fiber optic             No           No               No
# 3186-AJIEK     Fiber optic            Yes           No              Yes
#
#            TechSupport StreamingTV StreamingMovies MultipleLines  \
# customerID
# 7590-VHVEG          No          No              No            No
# 5575-GNVDE          No          No              No            No
# 3668-QPYBK          No          No              No            No
# 7795-CFOCW         Yes          No              No            No
# 9237-HQITU          No          No              No            No
# ...                ...         ...             ...           ...
# 6840-RESVB         Yes         Yes             Yes           Yes
# 2234-XADUH          No         Yes             Yes           Yes
# 4801-JZAZL          No          No              No            No
# 8361-LTMKD          No          No              No           Yes
# 3186-AJIEK         Yes         Yes             Yes            No
#
#             DurationContract_x
# customerID
# 7590-VHVEG                  31
# 5575-GNVDE                1036
# 3668-QPYBK                 123
# 7795-CFOCW                1371
# 9237-HQITU                 153
# ...                        ...
# 6840-RESVB                 730
# 2234-XADUH                2191
# 4801-JZAZL                 337
# 8361-LTMKD                 215
# 3186-AJIEK                2010
#
# [6851 rows x 17 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=RANDOM_STATE, stratify=y)

# %%
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
numerical_columns_selector = selector(dtype_exclude=object)
categorical_columns_selector = selector(dtype_include=object)

num_columns = numerical_columns_selector(data)
cat_columns = categorical_columns_selector(data)
num_columns.remove('EndDate_bool')
num_columns
# Out:
# ['MonthlyCharges', 'TotalCharges', 'DurationContract_x']

# %%
cat_columns
# Out:
# ['SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'Type',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'MultipleLines']

# %%
num_pipline = Pipeline([('scaler', StandardScaler())])

columns_pipeline=ColumnTransformer([('num_cols', num_pipline, num_columns),
                                    ('category_encoder',
                                        OrdinalEncoder(), cat_columns)])
columns_pipeline
# Out:
# ColumnTransformer(transformers=[('num_cols',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['MonthlyCharges', 'TotalCharges',
#                                   'DurationContract_x']),
#                                 ('category_encoder', OrdinalEncoder(),
#                                  ['SeniorCitizen', 'Partner', 'Dependents',
#                                   'Type', 'PaperlessBilling', 'PaymentMethod',
#                                   'InternetService', 'OnlineSecurity',
#                                   'OnlineBackup', 'DeviceProtection',
#                                   'TechSupport', 'StreamingTV',
#                                   'StreamingMovies', 'MultipleLines'])])

# %% [markdown]
# Добавила DropCorrelatedFeatures(). Эта функция может заметить то, чего не заметила я, лишней такая обработка данных не будет:)

# %%
pipeline = make_pipeline(columns_pipeline)
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_cols',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'DurationContract_x']),
#                                                  ('category_encoder',
#                                                   OrdinalEncoder(),
#                                                   ['SeniorCitizen', 'Partner',
#                                                    'Dependents', 'Type',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'MultipleLines'])]))])

# %% [markdown]
# ### LogisticRegression

# %%
pipeline.steps.append(('mod', LogisticRegression()))
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_cols',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'DurationContract_x']),
#                                                  ('category_encoder',
#                                                   OrdinalEncoder(),
#                                                   ['SeniorCitizen', 'Partner',
#                                                    'Dependents', 'Type',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'MultipleLines'])])),
#                 ('mod', LogisticRegression())])

# %%
params_LR = [{
        'mod__class_weight': [None, 'balanced'],
        'mod__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
        
    }]

grid_LR = RandomizedSearchCV(pipeline,
                    params_LR,
                    n_iter=10,
                    cv=3,
                    verbose=1,
                    random_state=RANDOM_STATE,
                    scoring='roc_auc',
                    n_jobs=-1)

# %%
# %%time

grid_LR.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# CPU times: user 902 ms, sys: 120 ms, total: 1.02 s
# Wall time: 3.39 s
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(transformers=[('num_cols',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['MonthlyCharges',
#                                                                                 'TotalCharges',
#                                                                                 'DurationContract_x']),
#                                                                               ('category_encoder',
#                                                                                OrdinalEncoder(),
#                                                                                ['SeniorCitizen',
#                                                                                 'Partner',
#                                                                                 'Dependents',
#                                                                                 'Type',
#                                                                                 'PaperlessBilling',
#                                                                                 'PaymentMethod',
#                                                                                 'InternetService',
#                                                                                 'OnlineSecurity',
#                                                                                 'OnlineBackup',
#                                                                                 'DeviceProtection',
#                                                                                 'TechSupport',
#                                                                                 'StreamingTV',
#                                                                                 'StreamingMovies',
#                                                                                 'MultipleLines'])])),
#                                              ('mod', LogisticRegression())]),
#                    n_jobs=-1,
#                    param_distributions=[{'mod__class_weight': [None,
#                                                                'balanced'],
#                                          'mod__solver': ['newton-cg', 'lbfgs',
#                                                          'liblinear', 'sag',
#                                                          'saga']}],
#                    random_state=240423, scoring='roc_auc', verbose=1)

# %%
#sklearn.metrics.get_scorer_names()

# %%
grid_LR.best_score_
# Out:
# 0.7552772015433966

# %%
model_LR = grid_LR.best_estimator_

# %%
grid_res = pd.DataFrame(grid_LR.cv_results_).sort_values(by='rank_test_score')

# %%
grid_res.iloc[0]['mean_fit_time'], grid_res.iloc[0]['mean_score_time']
# Out:
# (0.2119756539662679, 0.07600124677022298)

# %%
LR_fit_time = grid_res.iloc[0]['mean_fit_time']
LR_score_time = grid_res.iloc[0]['mean_score_time']

# %%
pipeline.steps.pop(1)
#pipeline
# Out:
# ('mod', LogisticRegression())

# %% [markdown]
# ### RandomForest

# %%
pipeline.steps.append(('mod', RandomForestClassifier()))
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_cols',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'DurationContract_x']),
#                                                  ('category_encoder',
#                                                   OrdinalEncoder(),
#                                                   ['SeniorCitizen', 'Partner',
#                                                    'Dependents', 'Type',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'MultipleLines'])])),
#                 ('mod', RandomForestClassifier())])

# %%
params_RF = [{
        'mod__n_estimators': range(2,500, 5),
        'mod__max_depth': range(5,250, 5),
        
    }]

grid_RF = RandomizedSearchCV(pipeline,
                    params_RF,
                    n_iter=50,
                    cv=5,
                    verbose=1,
                    random_state=RANDOM_STATE,
                    scoring='roc_auc',
                    n_jobs=-1)

# %%
# %%time

grid_RF.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# CPU times: user 7.88 s, sys: 293 ms, total: 8.18 s
# Wall time: 3min 23s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(transformers=[('num_cols',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['MonthlyCharges',
#                                                                                 'TotalCharges',
#                                                                                 'DurationContract_x']),
#                                                                               ('category_encoder',
#                                                                                OrdinalEncoder(),
#                                                                                ['SeniorCitizen',
#                                                                                 'Partner',
#                                                                                 'Dependents',
#                                                                                 'Type',
#                                                                                 'PaperlessBilling',
#                                                                                 'PaymentMethod',
#                                                                                 'InternetService',
#                                                                                 'OnlineSecurity',
#                                                                                 'OnlineBackup',
#                                                                                 'DeviceProtection',
#                                                                                 'TechSupport',
#                                                                                 'StreamingTV',
#                                                                                 'StreamingMovies',
#                                                                                 'MultipleLines'])])),
#                                              ('mod',
#                                               RandomForestClassifier())]),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions=[{'mod__max_depth': range(5, 250, 5),
#                                          'mod__n_estimators': range(2, 500, 5)}],
#                    random_state=240423, scoring='roc_auc', verbose=1)

# %%
model_RF = grid_RF.best_estimator_

# %%
grid_RF.best_score_
# Out:
# 0.8300361156145006

# %%
grid_res = pd.DataFrame(grid_RF.cv_results_).sort_values(by='rank_test_score')

# %%
grid_res.iloc[0]['mean_fit_time'], grid_res.iloc[0]['mean_score_time']
# Out:
# (6.016023397445679, 0.2699438095092773)

# %%
RF_fit_time = grid_res.iloc[0]['mean_fit_time']
RF_score_time = grid_res.iloc[0]['mean_score_time']

# %%
pipeline.steps.pop(1)
#pipeline
# Out:
# ('mod', RandomForestClassifier())

# %% [markdown]
# ### CatBoostClassifier

# %%
pipeline.steps.append(('mod', CatBoostClassifier()))
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_cols',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'DurationContract_x']),
#                                                  ('category_encoder',
#                                                   OrdinalEncoder(),
#                                                   ['SeniorCitizen', 'Partner',
#                                                    'Dependents', 'Type',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'MultipleLines'])])),
#                 ('mod',
#                  <catboost.core.CatBoostClassifier object at 0x7fc7c439c5e0>)])

# %%
params_CB = [{'mod__learning_rate': [0.01,0.03, 0.05, 0.1, 0.5,0.7],
        'mod__depth': [4, 6, 10, 15,20],
        'mod__l2_leaf_reg': [1, 3, 5, 7, 9],
        'mod__n_estimators': range(5,50,5)
    }]

grid_CB = RandomizedSearchCV(pipeline,
                    params_CB,
                    n_iter=150,
                    cv=5,
                    verbose=0,
                    random_state=RANDOM_STATE,
                    scoring='roc_auc')

# %%
# %%time

grid_CB.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6772769	total: 66.7ms	remaining: 934ms
# 1:	learn: 0.6629220	total: 94.2ms	remaining: 612ms
# 2:	learn: 0.6498554	total: 97.2ms	remaining: 389ms
# 3:	learn: 0.6365216	total: 123ms	remaining: 338ms
# 4:	learn: 0.6235140	total: 134ms	remaining: 269ms
# 5:	learn: 0.6110039	total: 160ms	remaining: 240ms
# 6:	learn: 0.5992582	total: 182ms	remaining: 208ms
# 7:	learn: 0.5881746	total: 185ms	remaining: 162ms
# 8:	learn: 0.5777632	total: 203ms	remaining: 135ms
# 9:	learn: 0.5683419	total: 221ms	remaining: 111ms
# 10:	learn: 0.5598206	total: 240ms	remaining: 87.3ms
# 11:	learn: 0.5505119	total: 259ms	remaining: 64.8ms
# 12:	learn: 0.5413517	total: 264ms	remaining: 40.6ms
# 13:	learn: 0.5329500	total: 284ms	remaining: 20.3ms
# 14:	learn: 0.5248683	total: 303ms	remaining: 0us
# 0:	learn: 0.6775730	total: 5.68ms	remaining: 79.6ms
# 1:	learn: 0.6632788	total: 22.3ms	remaining: 145ms
# 2:	learn: 0.6501568	total: 24.4ms	remaining: 97.6ms
# 3:	learn: 0.6378722	total: 39.9ms	remaining: 110ms
# 4:	learn: 0.6249645	total: 51.6ms	remaining: 103ms
# 5:	learn: 0.6123373	total: 57.5ms	remaining: 86.2ms
# 6:	learn: 0.6008657	total: 62.5ms	remaining: 71.4ms
# 7:	learn: 0.5913258	total: 63.4ms	remaining: 55.5ms
# 8:	learn: 0.5808560	total: 65.8ms	remaining: 43.8ms
# 9:	learn: 0.5714708	total: 81.3ms	remaining: 40.7ms
# 10:	learn: 0.5617659	total: 99.4ms	remaining: 36.1ms
# 11:	learn: 0.5532250	total: 116ms	remaining: 29ms
# 12:	learn: 0.5443182	total: 133ms	remaining: 20.5ms
# 13:	learn: 0.5361454	total: 137ms	remaining: 9.78ms
# 14:	learn: 0.5279316	total: 154ms	remaining: 0us
# 0:	learn: 0.6770374	total: 4.46ms	remaining: 62.4ms
# 1:	learn: 0.6629879	total: 19.7ms	remaining: 128ms
# 2:	learn: 0.6497602	total: 21.7ms	remaining: 86.8ms
# 3:	learn: 0.6363959	total: 36.9ms	remaining: 102ms
# 4:	learn: 0.6232330	total: 45.2ms	remaining: 90.5ms
# 5:	learn: 0.6107543	total: 60.9ms	remaining: 91.3ms
# 6:	learn: 0.5988958	total: 77.1ms	remaining: 88.1ms
# 7:	learn: 0.5876996	total: 80.3ms	remaining: 70.3ms
# 8:	learn: 0.5776194	total: 95.5ms	remaining: 63.7ms
# 9:	learn: 0.5673598	total: 112ms	remaining: 56ms
# 10:	learn: 0.5588129	total: 128ms	remaining: 46.7ms
# 11:	learn: 0.5497954	total: 145ms	remaining: 36.3ms
# 12:	learn: 0.5407556	total: 148ms	remaining: 22.8ms
# 13:	learn: 0.5323030	total: 165ms	remaining: 11.8ms
# 14:	learn: 0.5240216	total: 181ms	remaining: 0us
# 0:	learn: 0.6784151	total: 2.64ms	remaining: 37ms
# 1:	learn: 0.6643921	total: 24.1ms	remaining: 156ms
# 2:	learn: 0.6506448	total: 42.9ms	remaining: 172ms
# 3:	learn: 0.6375920	total: 62.6ms	remaining: 172ms
# 4:	learn: 0.6249515	total: 82.7ms	remaining: 165ms
# 5:	learn: 0.6126859	total: 90.3ms	remaining: 135ms
# 6:	learn: 0.6010065	total: 109ms	remaining: 124ms
# 7:	learn: 0.5911885	total: 111ms	remaining: 96.9ms
# 8:	learn: 0.5810851	total: 115ms	remaining: 76.9ms
# 9:	learn: 0.5715971	total: 118ms	remaining: 59ms
# 10:	learn: 0.5617720	total: 137ms	remaining: 49.9ms
# 11:	learn: 0.5528988	total: 140ms	remaining: 35.1ms
# 12:	learn: 0.5444461	total: 158ms	remaining: 24.4ms
# 13:	learn: 0.5362144	total: 176ms	remaining: 12.6ms
# 14:	learn: 0.5287347	total: 194ms	remaining: 0us
# 0:	learn: 0.6773003	total: 5.87ms	remaining: 82.2ms
# 1:	learn: 0.6629791	total: 21.9ms	remaining: 142ms
# 2:	learn: 0.6492108	total: 24ms	remaining: 96.1ms
# 3:	learn: 0.6359654	total: 41.8ms	remaining: 115ms
# 4:	learn: 0.6227977	total: 50.3ms	remaining: 101ms
# 5:	learn: 0.6102175	total: 55ms	remaining: 82.5ms
# 6:	learn: 0.5985022	total: 59.9ms	remaining: 68.5ms
# 7:	learn: 0.5889658	total: 60.6ms	remaining: 53.1ms
# 8:	learn: 0.5786187	total: 62.1ms	remaining: 41.4ms
# 9:	learn: 0.5693663	total: 77.7ms	remaining: 38.9ms
# 10:	learn: 0.5600574	total: 79.9ms	remaining: 29.1ms
# 11:	learn: 0.5510048	total: 88ms	remaining: 22ms
# 12:	learn: 0.5419863	total: 104ms	remaining: 15.9ms
# 13:	learn: 0.5335514	total: 118ms	remaining: 8.42ms
# 14:	learn: 0.5255817	total: 120ms	remaining: 0us
# 0:	learn: 0.6500786	total: 4.2ms	remaining: 79.7ms
# 1:	learn: 0.6203141	total: 17.3ms	remaining: 156ms
# 2:	learn: 0.5852581	total: 19.2ms	remaining: 109ms
# 3:	learn: 0.5609888	total: 32.7ms	remaining: 131ms
# 4:	learn: 0.5365166	total: 40.2ms	remaining: 120ms
# 5:	learn: 0.5189804	total: 56.7ms	remaining: 132ms
# 6:	learn: 0.5006327	total: 73.8ms	remaining: 137ms
# 7:	learn: 0.4827571	total: 77.7ms	remaining: 117ms
# 8:	learn: 0.4700880	total: 95.8ms	remaining: 117ms
# 9:	learn: 0.4577445	total: 105ms	remaining: 105ms
# 10:	learn: 0.4460510	total: 107ms	remaining: 87.7ms
# 11:	learn: 0.4372472	total: 125ms	remaining: 83.2ms
# 12:	learn: 0.4269970	total: 141ms	remaining: 76.2ms
# 13:	learn: 0.4190425	total: 159ms	remaining: 67.9ms
# 14:	learn: 0.4112281	total: 175ms	remaining: 58.4ms
# 15:	learn: 0.4030319	total: 180ms	remaining: 45.1ms
# 16:	learn: 0.3965634	total: 194ms	remaining: 34.3ms
# 17:	learn: 0.3906891	total: 210ms	remaining: 23.3ms
# 18:	learn: 0.3863663	total: 225ms	remaining: 11.8ms
# 19:	learn: 0.3819547	total: 240ms	remaining: 0us
# 0:	learn: 0.6519874	total: 4.37ms	remaining: 83ms
# 1:	learn: 0.6243989	total: 17.2ms	remaining: 155ms
# 2:	learn: 0.5902040	total: 19.1ms	remaining: 108ms
# 3:	learn: 0.5660247	total: 32.1ms	remaining: 128ms
# 4:	learn: 0.5414770	total: 39.4ms	remaining: 118ms
# 5:	learn: 0.5179597	total: 43.8ms	remaining: 102ms
# 6:	learn: 0.5021001	total: 57.4ms	remaining: 107ms
# 7:	learn: 0.4853275	total: 66.2ms	remaining: 99.3ms
# 8:	learn: 0.4733134	total: 81.1ms	remaining: 99.1ms
# 9:	learn: 0.4605455	total: 91.1ms	remaining: 91.1ms
# 10:	learn: 0.4500597	total: 107ms	remaining: 87.9ms
# 11:	learn: 0.4411732	total: 125ms	remaining: 83.1ms
# 12:	learn: 0.4306787	total: 146ms	remaining: 78.7ms
# 13:	learn: 0.4226132	total: 164ms	remaining: 70.5ms
# 14:	learn: 0.4162269	total: 182ms	remaining: 60.8ms
# 15:	learn: 0.4097827	total: 199ms	remaining: 49.8ms
# 16:	learn: 0.4037304	total: 215ms	remaining: 37.9ms
# 17:	learn: 0.3965881	total: 216ms	remaining: 24ms
# 18:	learn: 0.3901834	total: 220ms	remaining: 11.6ms
# 19:	learn: 0.3862794	total: 234ms	remaining: 0us
# 0:	learn: 0.6494941	total: 4.68ms	remaining: 89ms
# 1:	learn: 0.6217280	total: 19.4ms	remaining: 175ms
# 2:	learn: 0.5874294	total: 21.7ms	remaining: 123ms
# 3:	learn: 0.5617599	total: 37.3ms	remaining: 149ms
# 4:	learn: 0.5380744	total: 48.6ms	remaining: 146ms
# 5:	learn: 0.5143164	total: 55.3ms	remaining: 129ms
# 6:	learn: 0.4957372	total: 62.4ms	remaining: 116ms
# 7:	learn: 0.4793241	total: 63.6ms	remaining: 95.4ms
# 8:	learn: 0.4629528	total: 65.7ms	remaining: 80.3ms
# 9:	learn: 0.4506432	total: 85.9ms	remaining: 85.9ms
# 10:	learn: 0.4406162	total: 102ms	remaining: 83.1ms
# 11:	learn: 0.4320041	total: 119ms	remaining: 79.4ms
# 12:	learn: 0.4236728	total: 136ms	remaining: 73.1ms
# 13:	learn: 0.4141420	total: 141ms	remaining: 60.3ms
# 14:	learn: 0.4053290	total: 143ms	remaining: 47.7ms
# 15:	learn: 0.3996334	total: 156ms	remaining: 39.1ms
# 16:	learn: 0.3941151	total: 171ms	remaining: 30.1ms
# 17:	learn: 0.3882247	total: 185ms	remaining: 20.5ms
# 18:	learn: 0.3831212	total: 188ms	remaining: 9.87ms
# 19:	learn: 0.3766447	total: 192ms	remaining: 0us
# 0:	learn: 0.6491724	total: 1.97ms	remaining: 37.4ms
# 1:	learn: 0.6162688	total: 16.3ms	remaining: 146ms
# 2:	learn: 0.5907830	total: 30.3ms	remaining: 172ms
# 3:	learn: 0.5667792	total: 44.4ms	remaining: 178ms
# 4:	learn: 0.5442556	total: 58.1ms	remaining: 174ms
# 5:	learn: 0.5212705	total: 62.8ms	remaining: 146ms
# 6:	learn: 0.5016785	total: 65.7ms	remaining: 122ms
# 7:	learn: 0.4825273	total: 68.6ms	remaining: 103ms
# 8:	learn: 0.4710601	total: 82.8ms	remaining: 101ms
# 9:	learn: 0.4563439	total: 84.9ms	remaining: 84.9ms
# 10:	learn: 0.4461163	total: 98.2ms	remaining: 80.4ms
# 11:	learn: 0.4382325	total: 113ms	remaining: 75.1ms
# 12:	learn: 0.4296985	total: 128ms	remaining: 69ms
# 13:	learn: 0.4206463	total: 129ms	remaining: 55.5ms
# 14:	learn: 0.4132327	total: 145ms	remaining: 48.2ms
# 15:	learn: 0.4070359	total: 158ms	remaining: 39.6ms
# 16:	learn: 0.4002636	total: 174ms	remaining: 30.6ms
# 17:	learn: 0.3941338	total: 188ms	remaining: 20.9ms
# 18:	learn: 0.3893836	total: 204ms	remaining: 10.7ms
# 19:	learn: 0.3836018	total: 210ms	remaining: 0us
# 0:	learn: 0.6516361	total: 3.83ms	remaining: 72.7ms
# 1:	learn: 0.6180862	total: 14.8ms	remaining: 133ms
# 2:	learn: 0.5843838	total: 16.3ms	remaining: 92.2ms
# 3:	learn: 0.5593647	total: 27.9ms	remaining: 112ms
# 4:	learn: 0.5348628	total: 34.6ms	remaining: 104ms
# 5:	learn: 0.5121673	total: 38.5ms	remaining: 89.9ms
# 6:	learn: 0.4964267	total: 51ms	remaining: 94.7ms
# 7:	learn: 0.4804348	total: 58.4ms	remaining: 87.5ms
# 8:	learn: 0.4669298	total: 72.6ms	remaining: 88.8ms
# 9:	learn: 0.4552820	total: 80.6ms	remaining: 80.6ms
# 10:	learn: 0.4451777	total: 95.7ms	remaining: 78.3ms
# 11:	learn: 0.4362171	total: 111ms	remaining: 73.9ms
# 12:	learn: 0.4259168	total: 126ms	remaining: 68ms
# 13:	learn: 0.4180071	total: 142ms	remaining: 60.8ms
# 14:	learn: 0.4113589	total: 157ms	remaining: 52.3ms
# 15:	learn: 0.4027238	total: 166ms	remaining: 41.5ms
# 16:	learn: 0.3959662	total: 182ms	remaining: 32.2ms
# 17:	learn: 0.3891295	total: 186ms	remaining: 20.6ms
# 18:	learn: 0.3838566	total: 200ms	remaining: 10.5ms
# 19:	learn: 0.3780982	total: 202ms	remaining: 0us
# 0:	learn: 0.5130092	total: 905us	remaining: 3.62ms
# 1:	learn: 0.4305041	total: 1.78ms	remaining: 2.67ms
# 2:	learn: 0.3962123	total: 2.73ms	remaining: 1.82ms
# 3:	learn: 0.3701921	total: 3.78ms	remaining: 945us
# 4:	learn: 0.3555649	total: 5.46ms	remaining: 0us
# 0:	learn: 0.5189013	total: 956us	remaining: 3.82ms
# 1:	learn: 0.4345586	total: 1.95ms	remaining: 2.92ms
# 2:	learn: 0.3930094	total: 2.86ms	remaining: 1.9ms
# 3:	learn: 0.3723003	total: 3.89ms	remaining: 972us
# 4:	learn: 0.3564655	total: 4.88ms	remaining: 0us
# 0:	learn: 0.5137769	total: 968us	remaining: 3.87ms
# 1:	learn: 0.4281442	total: 1.91ms	remaining: 2.86ms
# 2:	learn: 0.3889305	total: 2.75ms	remaining: 1.83ms
# 3:	learn: 0.3653327	total: 3.65ms	remaining: 911us
# 4:	learn: 0.3544024	total: 4.5ms	remaining: 0us
# 0:	learn: 0.5152398	total: 1.44ms	remaining: 5.74ms
# 1:	learn: 0.4340917	total: 3.16ms	remaining: 4.74ms
# 2:	learn: 0.3963037	total: 4.46ms	remaining: 2.97ms
# 3:	learn: 0.3733138	total: 5.9ms	remaining: 1.48ms
# 4:	learn: 0.3618643	total: 7.13ms	remaining: 0us
# 0:	learn: 0.5184357	total: 937us	remaining: 3.75ms
# 1:	learn: 0.4340514	total: 1.85ms	remaining: 2.78ms
# 2:	learn: 0.3966403	total: 2.74ms	remaining: 1.83ms
# 3:	learn: 0.3692709	total: 3.75ms	remaining: 937us
# 4:	learn: 0.3552619	total: 4.85ms	remaining: 0us
# 0:	learn: 0.6883571	total: 945us	remaining: 22.7ms
# 1:	learn: 0.6833031	total: 1.69ms	remaining: 19.4ms
# 2:	learn: 0.6785225	total: 2.51ms	remaining: 18.4ms
# 3:	learn: 0.6736884	total: 3.34ms	remaining: 17.5ms
# 4:	learn: 0.6691778	total: 4.19ms	remaining: 16.8ms
# 5:	learn: 0.6648595	total: 5.18ms	remaining: 16.4ms
# 6:	learn: 0.6605523	total: 5.99ms	remaining: 15.4ms
# 7:	learn: 0.6564001	total: 6.78ms	remaining: 14.4ms
# 8:	learn: 0.6522475	total: 7.8ms	remaining: 13.9ms
# 9:	learn: 0.6480143	total: 8.64ms	remaining: 13ms
# 10:	learn: 0.6438064	total: 9.43ms	remaining: 12ms
# 11:	learn: 0.6395282	total: 10.3ms	remaining: 11.2ms
# 12:	learn: 0.6357151	total: 11.2ms	remaining: 10.3ms
# 13:	learn: 0.6316937	total: 12ms	remaining: 9.44ms
# 14:	learn: 0.6278864	total: 12.9ms	remaining: 8.6ms
# 15:	learn: 0.6239901	total: 13.7ms	remaining: 7.71ms
# 16:	learn: 0.6205091	total: 14.6ms	remaining: 6.87ms
# 17:	learn: 0.6170252	total: 15.4ms	remaining: 6.01ms
# 18:	learn: 0.6136164	total: 16.2ms	remaining: 5.13ms
# 19:	learn: 0.6099717	total: 18.2ms	remaining: 4.54ms
# 20:	learn: 0.6064819	total: 19.1ms	remaining: 3.64ms
# 21:	learn: 0.6032206	total: 20.2ms	remaining: 2.75ms
# 22:	learn: 0.5997435	total: 21.2ms	remaining: 1.84ms
# 23:	learn: 0.5963464	total: 22.3ms	remaining: 929us
# 24:	learn: 0.5932479	total: 23.5ms	remaining: 0us
# 0:	learn: 0.6884971	total: 1.03ms	remaining: 24.7ms
# 1:	learn: 0.6834600	total: 2.04ms	remaining: 23.4ms
# 2:	learn: 0.6787676	total: 2.96ms	remaining: 21.7ms
# 3:	learn: 0.6740294	total: 4.09ms	remaining: 21.5ms
# 4:	learn: 0.6695850	total: 5.04ms	remaining: 20.2ms
# 5:	learn: 0.6653050	total: 6ms	remaining: 19ms
# 6:	learn: 0.6610286	total: 7.22ms	remaining: 18.6ms
# 7:	learn: 0.6569089	total: 8.33ms	remaining: 17.7ms
# 8:	learn: 0.6527847	total: 9.25ms	remaining: 16.4ms
# 9:	learn: 0.6487283	total: 10.3ms	remaining: 15.4ms
# 10:	learn: 0.6445399	total: 11.3ms	remaining: 14.3ms
# 11:	learn: 0.6406267	total: 12.2ms	remaining: 13.2ms
# 12:	learn: 0.6368551	total: 13.2ms	remaining: 12.1ms
# 13:	learn: 0.6329996	total: 14.5ms	remaining: 11.4ms
# 14:	learn: 0.6291265	total: 15.6ms	remaining: 10.4ms
# 15:	learn: 0.6251845	total: 16.6ms	remaining: 9.32ms
# 16:	learn: 0.6215690	total: 17.6ms	remaining: 8.29ms
# 17:	learn: 0.6181039	total: 18.6ms	remaining: 7.23ms
# 18:	learn: 0.6145212	total: 19.6ms	remaining: 6.19ms
# 19:	learn: 0.6109278	total: 20.5ms	remaining: 5.12ms
# 20:	learn: 0.6073889	total: 21.6ms	remaining: 4.12ms
# 21:	learn: 0.6041678	total: 22.9ms	remaining: 3.12ms
# 22:	learn: 0.6006946	total: 23.8ms	remaining: 2.07ms
# 23:	learn: 0.5972954	total: 24.9ms	remaining: 1.04ms
# 24:	learn: 0.5942073	total: 25.9ms	remaining: 0us
# 0:	learn: 0.6883745	total: 1.72ms	remaining: 41.2ms
# 1:	learn: 0.6832474	total: 3.14ms	remaining: 36.1ms
# 2:	learn: 0.6784957	total: 5.31ms	remaining: 38.9ms
# 3:	learn: 0.6736620	total: 6.43ms	remaining: 33.8ms
# 4:	learn: 0.6692465	total: 7.74ms	remaining: 30.9ms
# 5:	learn: 0.6649156	total: 8.94ms	remaining: 28.3ms
# 6:	learn: 0.6606054	total: 10.6ms	remaining: 27.2ms
# 7:	learn: 0.6564359	total: 12ms	remaining: 25.6ms
# 8:	learn: 0.6523825	total: 13.3ms	remaining: 23.7ms
# 9:	learn: 0.6481828	total: 14.8ms	remaining: 22.2ms
# 10:	learn: 0.6440910	total: 16.6ms	remaining: 21.2ms
# 11:	learn: 0.6400757	total: 18.4ms	remaining: 19.9ms
# 12:	learn: 0.6361980	total: 20.1ms	remaining: 18.6ms
# 13:	learn: 0.6320638	total: 21.9ms	remaining: 17.2ms
# 14:	learn: 0.6281578	total: 23.5ms	remaining: 15.7ms
# 15:	learn: 0.6242373	total: 24.9ms	remaining: 14ms
# 16:	learn: 0.6207326	total: 26.3ms	remaining: 12.4ms
# 17:	learn: 0.6171758	total: 27.6ms	remaining: 10.7ms
# 18:	learn: 0.6134380	total: 29.1ms	remaining: 9.18ms
# 19:	learn: 0.6097262	total: 30.5ms	remaining: 7.63ms
# 20:	learn: 0.6060825	total: 31.8ms	remaining: 6.06ms
# 21:	learn: 0.6025675	total: 33.4ms	remaining: 4.55ms
# 22:	learn: 0.5992675	total: 35.4ms	remaining: 3.08ms
# 23:	learn: 0.5959173	total: 37.3ms	remaining: 1.55ms
# 24:	learn: 0.5924895	total: 39.1ms	remaining: 0us
# 0:	learn: 0.6884056	total: 1.2ms	remaining: 28.7ms
# 1:	learn: 0.6833777	total: 2.45ms	remaining: 28.2ms
# 2:	learn: 0.6787552	total: 3.53ms	remaining: 25.9ms
# 3:	learn: 0.6740024	total: 4.66ms	remaining: 24.4ms
# 4:	learn: 0.6695711	total: 5.78ms	remaining: 23.1ms
# 5:	learn: 0.6653345	total: 6.9ms	remaining: 21.9ms
# 6:	learn: 0.6608801	total: 8.27ms	remaining: 21.3ms
# 7:	learn: 0.6567727	total: 9.36ms	remaining: 19.9ms
# 8:	learn: 0.6527465	total: 10.2ms	remaining: 18.1ms
# 9:	learn: 0.6485503	total: 11.3ms	remaining: 16.9ms
# 10:	learn: 0.6442934	total: 12.4ms	remaining: 15.8ms
# 11:	learn: 0.6403050	total: 13.4ms	remaining: 14.5ms
# 12:	learn: 0.6364484	total: 14.4ms	remaining: 13.3ms
# 13:	learn: 0.6323248	total: 15.4ms	remaining: 12.1ms
# 14:	learn: 0.6286103	total: 16.5ms	remaining: 11ms
# 15:	learn: 0.6247163	total: 17.6ms	remaining: 9.92ms
# 16:	learn: 0.6212335	total: 19ms	remaining: 8.95ms
# 17:	learn: 0.6176999	total: 20.1ms	remaining: 7.82ms
# 18:	learn: 0.6140418	total: 21.6ms	remaining: 6.81ms
# 19:	learn: 0.6104265	total: 22.7ms	remaining: 5.67ms
# 20:	learn: 0.6068667	total: 23.8ms	remaining: 4.54ms
# 21:	learn: 0.6034307	total: 24.9ms	remaining: 3.4ms
# 22:	learn: 0.6001270	total: 26.2ms	remaining: 2.28ms
# 23:	learn: 0.5968506	total: 27.6ms	remaining: 1.15ms
# 24:	learn: 0.5934700	total: 28.8ms	remaining: 0us
# 0:	learn: 0.6884885	total: 1.39ms	remaining: 33.3ms
# 1:	learn: 0.6835767	total: 3.09ms	remaining: 35.6ms
# 2:	learn: 0.6788113	total: 4.26ms	remaining: 31.2ms
# 3:	learn: 0.6740331	total: 5.29ms	remaining: 27.8ms
# 4:	learn: 0.6696262	total: 6.39ms	remaining: 25.6ms
# 5:	learn: 0.6653403	total: 7.58ms	remaining: 24ms
# 6:	learn: 0.6610299	total: 9.03ms	remaining: 23.2ms
# 7:	learn: 0.6568831	total: 11.1ms	remaining: 23.6ms
# 8:	learn: 0.6528169	total: 12.3ms	remaining: 21.8ms
# 9:	learn: 0.6486522	total: 14.2ms	remaining: 21.3ms
# 10:	learn: 0.6445646	total: 16ms	remaining: 20.4ms
# 11:	learn: 0.6405710	total: 17.8ms	remaining: 19.3ms
# 12:	learn: 0.6366486	total: 19.9ms	remaining: 18.4ms
# 13:	learn: 0.6325388	total: 22ms	remaining: 17.3ms
# 14:	learn: 0.6286481	total: 24ms	remaining: 16ms
# 15:	learn: 0.6247016	total: 25.9ms	remaining: 14.6ms
# 16:	learn: 0.6212284	total: 27.4ms	remaining: 12.9ms
# 17:	learn: 0.6174909	total: 28.9ms	remaining: 11.2ms
# 18:	learn: 0.6138232	total: 30.1ms	remaining: 9.52ms
# 19:	learn: 0.6101847	total: 32.1ms	remaining: 8.02ms
# 20:	learn: 0.6065794	total: 33.2ms	remaining: 6.32ms
# 21:	learn: 0.6031621	total: 34.7ms	remaining: 4.73ms
# 22:	learn: 0.5998361	total: 36ms	remaining: 3.13ms
# 23:	learn: 0.5964583	total: 37.6ms	remaining: 1.57ms
# 24:	learn: 0.5933256	total: 39.1ms	remaining: 0us
# 0:	learn: 0.6500786	total: 4.65ms	remaining: 65.1ms
# 1:	learn: 0.6203141	total: 16.2ms	remaining: 105ms
# 2:	learn: 0.5852581	total: 17.7ms	remaining: 70.7ms
# 3:	learn: 0.5609888	total: 29.7ms	remaining: 81.7ms
# 4:	learn: 0.5365166	total: 36.2ms	remaining: 72.4ms
# 5:	learn: 0.5189804	total: 49.1ms	remaining: 73.6ms
# 6:	learn: 0.5006327	total: 63.1ms	remaining: 72.1ms
# 7:	learn: 0.4827571	total: 66.1ms	remaining: 57.8ms
# 8:	learn: 0.4700880	total: 80.7ms	remaining: 53.8ms
# 9:	learn: 0.4577445	total: 89.9ms	remaining: 45ms
# 10:	learn: 0.4460510	total: 92.1ms	remaining: 33.5ms
# 11:	learn: 0.4372472	total: 108ms	remaining: 26.9ms
# 12:	learn: 0.4269970	total: 123ms	remaining: 18.9ms
# 13:	learn: 0.4190425	total: 138ms	remaining: 9.88ms
# 14:	learn: 0.4112281	total: 155ms	remaining: 0us
# 0:	learn: 0.6519874	total: 3.86ms	remaining: 54ms
# 1:	learn: 0.6243989	total: 16.8ms	remaining: 109ms
# 2:	learn: 0.5902040	total: 18.6ms	remaining: 74.5ms
# 3:	learn: 0.5660247	total: 31.4ms	remaining: 86.4ms
# 4:	learn: 0.5414770	total: 40.6ms	remaining: 81.2ms
# 5:	learn: 0.5179597	total: 45.3ms	remaining: 68ms
# 6:	learn: 0.5021001	total: 61.3ms	remaining: 70ms
# 7:	learn: 0.4853275	total: 70.4ms	remaining: 61.6ms
# 8:	learn: 0.4733134	total: 86.7ms	remaining: 57.8ms
# 9:	learn: 0.4605455	total: 95.2ms	remaining: 47.6ms
# 10:	learn: 0.4500597	total: 110ms	remaining: 40.2ms
# 11:	learn: 0.4411732	total: 126ms	remaining: 31.4ms
# 12:	learn: 0.4306787	total: 139ms	remaining: 21.4ms
# 13:	learn: 0.4226132	total: 152ms	remaining: 10.9ms
# 14:	learn: 0.4162269	total: 166ms	remaining: 0us
# 0:	learn: 0.6494941	total: 4.86ms	remaining: 68.1ms
# 1:	learn: 0.6217280	total: 19ms	remaining: 124ms
# 2:	learn: 0.5874294	total: 20.9ms	remaining: 83.7ms
# 3:	learn: 0.5617599	total: 35.7ms	remaining: 98.2ms
# 4:	learn: 0.5380744	total: 45ms	remaining: 90.1ms
# 5:	learn: 0.5143164	total: 50.1ms	remaining: 75.2ms
# 6:	learn: 0.4957372	total: 55.2ms	remaining: 63.1ms
# 7:	learn: 0.4793241	total: 56ms	remaining: 49ms
# 8:	learn: 0.4629528	total: 57.5ms	remaining: 38.3ms
# 9:	learn: 0.4506432	total: 72.6ms	remaining: 36.3ms
# 10:	learn: 0.4406162	total: 87.2ms	remaining: 31.7ms
# 11:	learn: 0.4320041	total: 101ms	remaining: 25.3ms
# 12:	learn: 0.4236728	total: 115ms	remaining: 17.8ms
# 13:	learn: 0.4141420	total: 120ms	remaining: 8.6ms
# 14:	learn: 0.4053290	total: 122ms	remaining: 0us
# 0:	learn: 0.6491724	total: 1.39ms	remaining: 19.5ms
# 1:	learn: 0.6162688	total: 13.6ms	remaining: 88.7ms
# 2:	learn: 0.5907830	total: 27.4ms	remaining: 109ms
# 3:	learn: 0.5667792	total: 42.2ms	remaining: 116ms
# 4:	learn: 0.5442556	total: 58.6ms	remaining: 117ms
# 5:	learn: 0.5212705	total: 63.6ms	remaining: 95.4ms
# 6:	learn: 0.5016785	total: 66.6ms	remaining: 76.1ms
# 7:	learn: 0.4825273	total: 69.6ms	remaining: 60.9ms
# 8:	learn: 0.4710601	total: 84.3ms	remaining: 56.2ms
# 9:	learn: 0.4563439	total: 86.3ms	remaining: 43.2ms
# 10:	learn: 0.4461163	total: 100ms	remaining: 36.5ms
# 11:	learn: 0.4382325	total: 114ms	remaining: 28.6ms
# 12:	learn: 0.4296985	total: 128ms	remaining: 19.7ms
# 13:	learn: 0.4206463	total: 129ms	remaining: 9.24ms
# 14:	learn: 0.4132327	total: 143ms	remaining: 0us
# 0:	learn: 0.6516361	total: 4.37ms	remaining: 61.2ms
# 1:	learn: 0.6180862	total: 17.8ms	remaining: 115ms
# 2:	learn: 0.5843838	total: 19.7ms	remaining: 78.9ms
# 3:	learn: 0.5593647	total: 32.3ms	remaining: 88.8ms
# 4:	learn: 0.5348628	total: 39.8ms	remaining: 79.6ms
# 5:	learn: 0.5121673	total: 44.2ms	remaining: 66.4ms
# 6:	learn: 0.4964267	total: 58.1ms	remaining: 66.4ms
# 7:	learn: 0.4804348	total: 65.8ms	remaining: 57.6ms
# 8:	learn: 0.4669298	total: 79.4ms	remaining: 52.9ms
# 9:	learn: 0.4552820	total: 87ms	remaining: 43.5ms
# 10:	learn: 0.4451777	total: 100ms	remaining: 36.5ms
# 11:	learn: 0.4362171	total: 114ms	remaining: 28.5ms
# 12:	learn: 0.4259168	total: 128ms	remaining: 19.7ms
# 13:	learn: 0.4180071	total: 142ms	remaining: 10.1ms
# 14:	learn: 0.4113589	total: 156ms	remaining: 0us
# 0:	learn: 0.4745913	total: 4.47ms	remaining: 62.6ms
# 1:	learn: 0.4239033	total: 71.9ms	remaining: 467ms
# 2:	learn: 0.3961682	total: 1.44s	remaining: 5.75s
# 3:	learn: 0.3615403	total: 1.45s	remaining: 3.98s
# 4:	learn: 0.3425963	total: 1.45s	remaining: 2.9s
# 5:	learn: 0.3344918	total: 2.19s	remaining: 3.28s
# 6:	learn: 0.3257321	total: 2.78s	remaining: 3.18s
# 7:	learn: 0.3170027	total: 3.38s	remaining: 2.96s
# 8:	learn: 0.3094700	total: 4.16s	remaining: 2.77s
# 9:	learn: 0.3021553	total: 5.03s	remaining: 2.51s
# 10:	learn: 0.2953252	total: 5.71s	remaining: 2.07s
# 11:	learn: 0.2895857	total: 6.39s	remaining: 1.6s
# 12:	learn: 0.2838859	total: 7.24s	remaining: 1.11s
# 13:	learn: 0.2786657	total: 8.02s	remaining: 573ms
# 14:	learn: 0.2734614	total: 8.9s	remaining: 0us
# 0:	learn: 0.4830954	total: 8.09ms	remaining: 113ms
# 1:	learn: 0.4256311	total: 74.9ms	remaining: 487ms
# 2:	learn: 0.3998152	total: 919ms	remaining: 3.68s
# 3:	learn: 0.3697736	total: 941ms	remaining: 2.59s
# 4:	learn: 0.3446621	total: 942ms	remaining: 1.88s
# 5:	learn: 0.3369911	total: 1.61s	remaining: 2.41s
# 6:	learn: 0.3285052	total: 2.37s	remaining: 2.71s
# 7:	learn: 0.3215471	total: 3.1s	remaining: 2.71s
# 8:	learn: 0.3145758	total: 3.76s	remaining: 2.5s
# 9:	learn: 0.3074091	total: 4.65s	remaining: 2.32s
# 10:	learn: 0.3010460	total: 5.36s	remaining: 1.95s
# 11:	learn: 0.2950791	total: 6.06s	remaining: 1.51s
# 12:	learn: 0.2891824	total: 6.84s	remaining: 1.05s
# 13:	learn: 0.2829332	total: 7.71s	remaining: 550ms
# 14:	learn: 0.2773507	total: 8.43s	remaining: 0us
# 0:	learn: 0.4712999	total: 5.79ms	remaining: 81ms
# 1:	learn: 0.4179002	total: 78.1ms	remaining: 508ms
# 2:	learn: 0.3922165	total: 897ms	remaining: 3.59s
# 3:	learn: 0.3762766	total: 1.81s	remaining: 4.97s
# 4:	learn: 0.3592661	total: 2.57s	remaining: 5.13s
# 5:	learn: 0.3479180	total: 3.4s	remaining: 5.11s
# 6:	learn: 0.3373561	total: 4.25s	remaining: 4.86s
# 7:	learn: 0.3286948	total: 5.09s	remaining: 4.45s
# 8:	learn: 0.3198575	total: 5.89s	remaining: 3.93s
# 9:	learn: 0.3119382	total: 6.68s	remaining: 3.34s
# 10:	learn: 0.3037032	total: 7.45s	remaining: 2.71s
# 11:	learn: 0.2970181	total: 8.13s	remaining: 2.03s
# 12:	learn: 0.2906107	total: 8.91s	remaining: 1.37s
# 13:	learn: 0.2843864	total: 9.66s	remaining: 690ms
# 14:	learn: 0.2786992	total: 10.4s	remaining: 0us
# 0:	learn: 0.4733494	total: 1.43ms	remaining: 20.1ms
# 1:	learn: 0.4274012	total: 1.43ms	remaining: 20.1ms
# 2:	learn: 0.4007155	total: 1.43ms	remaining: 20.1ms
# 3:	learn: 0.3657045	total: 4.25ms	remaining: 23.4ms
# 4:	learn: 0.3524357	total: 4.25ms	remaining: 23.4ms
# 5:	learn: 0.3421499	total: 4.25ms	remaining: 23.4ms
# 6:	learn: 0.3322708	total: 4.25ms	remaining: 23.4ms
# 7:	learn: 0.3199543	total: 6.67ms	remaining: 15.6ms
# 8:	learn: 0.3122517	total: 6.67ms	remaining: 15.6ms
# 9:	learn: 0.3036028	total: 7.92ms	remaining: 9.9ms
# 10:	learn: 0.2971214	total: 7.92ms	remaining: 9.9ms
# 11:	learn: 0.2905550	total: 7.92ms	remaining: 9.9ms
# 12:	learn: 0.2843869	total: 7.92ms	remaining: 9.9ms
# 13:	learn: 0.2788762	total: 7.92ms	remaining: 9.9ms
# 14:	learn: 0.2730503	total: 7.92ms	remaining: 9.9ms
# 0:	learn: 0.4814168	total: 4.59ms	remaining: 64.2ms
# 1:	learn: 0.4161664	total: 71.5ms	remaining: 465ms
# 2:	learn: 0.3919540	total: 820ms	remaining: 3.28s
# 3:	learn: 0.3629807	total: 823ms	remaining: 2.26s
# 4:	learn: 0.3504623	total: 1.45s	remaining: 2.9s
# 5:	learn: 0.3413228	total: 2.1s	remaining: 3.14s
# 6:	learn: 0.3331126	total: 2.72s	remaining: 3.11s
# 7:	learn: 0.3249566	total: 3.42s	remaining: 3s
# 8:	learn: 0.3176727	total: 4.08s	remaining: 2.72s
# 9:	learn: 0.3106237	total: 4.68s	remaining: 2.34s
# 10:	learn: 0.3039900	total: 5.32s	remaining: 1.93s
# 11:	learn: 0.2928458	total: 5.32s	remaining: 1.33s
# 12:	learn: 0.2868900	total: 5.96s	remaining: 916ms
# 13:	learn: 0.2813054	total: 6.59s	remaining: 471ms
# 14:	learn: 0.2760693	total: 7.17s	remaining: 0us
# 0:	learn: 0.4787229	total: 1.96ms	remaining: 17.6ms
# 1:	learn: 0.4062733	total: 4.02ms	remaining: 16.1ms
# 2:	learn: 0.3748175	total: 5.79ms	remaining: 13.5ms
# 3:	learn: 0.3532632	total: 7.63ms	remaining: 11.4ms
# 4:	learn: 0.3392963	total: 9.78ms	remaining: 9.78ms
# 5:	learn: 0.3313459	total: 11.8ms	remaining: 7.85ms
# 6:	learn: 0.3246641	total: 13.9ms	remaining: 5.94ms
# 7:	learn: 0.3213400	total: 15.9ms	remaining: 3.97ms
# 8:	learn: 0.3176098	total: 18ms	remaining: 2ms
# 9:	learn: 0.3148585	total: 20ms	remaining: 0us
# 0:	learn: 0.4862132	total: 1.78ms	remaining: 16.1ms
# 1:	learn: 0.4104376	total: 3.88ms	remaining: 15.5ms
# 2:	learn: 0.3684505	total: 5.63ms	remaining: 13.1ms
# 3:	learn: 0.3515588	total: 7.51ms	remaining: 11.3ms
# 4:	learn: 0.3407521	total: 9.41ms	remaining: 9.41ms
# 5:	learn: 0.3322761	total: 11.4ms	remaining: 7.61ms
# 6:	learn: 0.3273599	total: 13.4ms	remaining: 5.74ms
# 7:	learn: 0.3240558	total: 15.4ms	remaining: 3.86ms
# 8:	learn: 0.3208296	total: 17.3ms	remaining: 1.92ms
# 9:	learn: 0.3194018	total: 19.4ms	remaining: 0us
# 0:	learn: 0.4773251	total: 2.11ms	remaining: 19ms
# 1:	learn: 0.4037223	total: 4.04ms	remaining: 16.2ms
# 2:	learn: 0.3613316	total: 6ms	remaining: 14ms
# 3:	learn: 0.3427638	total: 7.73ms	remaining: 11.6ms
# 4:	learn: 0.3321620	total: 9.8ms	remaining: 9.8ms
# 5:	learn: 0.3253575	total: 11.6ms	remaining: 7.76ms
# 6:	learn: 0.3213000	total: 13.6ms	remaining: 5.82ms
# 7:	learn: 0.3176281	total: 15.5ms	remaining: 3.88ms
# 8:	learn: 0.3152604	total: 16.6ms	remaining: 1.84ms
# 9:	learn: 0.3120036	total: 18.5ms	remaining: 0us
# 0:	learn: 0.4733494	total: 2.49ms	remaining: 22.4ms
# 1:	learn: 0.4030362	total: 4.8ms	remaining: 19.2ms
# 2:	learn: 0.3658168	total: 7.13ms	remaining: 16.6ms
# 3:	learn: 0.3498702	total: 9.45ms	remaining: 14.2ms
# 4:	learn: 0.3391697	total: 11.4ms	remaining: 11.4ms
# 5:	learn: 0.3330856	total: 13.6ms	remaining: 9.06ms
# 6:	learn: 0.3292535	total: 15.9ms	remaining: 6.82ms
# 7:	learn: 0.3246526	total: 17.8ms	remaining: 4.46ms
# 8:	learn: 0.3208985	total: 19.8ms	remaining: 2.2ms
# 9:	learn: 0.3195992	total: 22ms	remaining: 0us
# 0:	learn: 0.4851197	total: 1.67ms	remaining: 15.1ms
# 1:	learn: 0.4048540	total: 3.66ms	remaining: 14.6ms
# 2:	learn: 0.3634792	total: 5.79ms	remaining: 13.5ms
# 3:	learn: 0.3480648	total: 7.79ms	remaining: 11.7ms
# 4:	learn: 0.3392118	total: 9.68ms	remaining: 9.68ms
# 5:	learn: 0.3330695	total: 12.2ms	remaining: 8.16ms
# 6:	learn: 0.3277509	total: 14.3ms	remaining: 6.15ms
# 7:	learn: 0.3233869	total: 16.4ms	remaining: 4.09ms
# 8:	learn: 0.3197567	total: 18.6ms	remaining: 2.07ms
# 9:	learn: 0.3180643	total: 20.5ms	remaining: 0us
# 0:	learn: 0.5062209	total: 1.93ms	remaining: 27ms
# 1:	learn: 0.4224469	total: 4.08ms	remaining: 26.5ms
# 2:	learn: 0.3850913	total: 5.92ms	remaining: 23.7ms
# 3:	learn: 0.3623920	total: 7.82ms	remaining: 21.5ms
# 4:	learn: 0.3485810	total: 9.58ms	remaining: 19.2ms
# 5:	learn: 0.3386773	total: 12ms	remaining: 17.9ms
# 6:	learn: 0.3346123	total: 14.2ms	remaining: 16.2ms
# 7:	learn: 0.3315938	total: 15.8ms	remaining: 13.8ms
# 8:	learn: 0.3289566	total: 17.3ms	remaining: 11.6ms
# 9:	learn: 0.3266527	total: 18.9ms	remaining: 9.43ms
# 10:	learn: 0.3221648	total: 20.7ms	remaining: 7.53ms
# 11:	learn: 0.3197250	total: 22.6ms	remaining: 5.64ms
# 12:	learn: 0.3184834	total: 24ms	remaining: 3.69ms
# 13:	learn: 0.3142087	total: 25.5ms	remaining: 1.82ms
# 14:	learn: 0.3118888	total: 27.6ms	remaining: 0us
# 0:	learn: 0.5102111	total: 1.73ms	remaining: 24.2ms
# 1:	learn: 0.4252945	total: 3.4ms	remaining: 22.1ms
# 2:	learn: 0.3841822	total: 5.07ms	remaining: 20.3ms
# 3:	learn: 0.3645110	total: 6.55ms	remaining: 18ms
# 4:	learn: 0.3516875	total: 8.05ms	remaining: 16.1ms
# 5:	learn: 0.3452002	total: 9.35ms	remaining: 14ms
# 6:	learn: 0.3384508	total: 10.6ms	remaining: 12.1ms
# 7:	learn: 0.3346509	total: 12ms	remaining: 10.5ms
# 8:	learn: 0.3297493	total: 13.6ms	remaining: 9.06ms
# 9:	learn: 0.3269277	total: 14.8ms	remaining: 7.41ms
# 10:	learn: 0.3242151	total: 15.9ms	remaining: 5.79ms
# 11:	learn: 0.3215729	total: 17.2ms	remaining: 4.3ms
# 12:	learn: 0.3211676	total: 18.6ms	remaining: 2.86ms
# 13:	learn: 0.3181362	total: 20.1ms	remaining: 1.44ms
# 14:	learn: 0.3163998	total: 21.7ms	remaining: 0us
# 0:	learn: 0.5067219	total: 1.35ms	remaining: 18.9ms
# 1:	learn: 0.4193147	total: 3.11ms	remaining: 20.2ms
# 2:	learn: 0.3809393	total: 4.19ms	remaining: 16.8ms
# 3:	learn: 0.3573369	total: 5.97ms	remaining: 16.4ms
# 4:	learn: 0.3464231	total: 7.6ms	remaining: 15.2ms
# 5:	learn: 0.3400580	total: 8.89ms	remaining: 13.3ms
# 6:	learn: 0.3322681	total: 10.1ms	remaining: 11.5ms
# 7:	learn: 0.3282433	total: 11.3ms	remaining: 9.9ms
# 8:	learn: 0.3251097	total: 12.9ms	remaining: 8.59ms
# 9:	learn: 0.3225579	total: 14.1ms	remaining: 7.06ms
# 10:	learn: 0.3197046	total: 15.3ms	remaining: 5.56ms
# 11:	learn: 0.3165231	total: 16.4ms	remaining: 4.1ms
# 12:	learn: 0.3164615	total: 17.7ms	remaining: 2.73ms
# 13:	learn: 0.3152586	total: 19.3ms	remaining: 1.38ms
# 14:	learn: 0.3130627	total: 21.1ms	remaining: 0us
# 0:	learn: 0.5078162	total: 2.25ms	remaining: 31.6ms
# 1:	learn: 0.4254432	total: 4.41ms	remaining: 28.7ms
# 2:	learn: 0.3839329	total: 6.67ms	remaining: 26.7ms
# 3:	learn: 0.3653876	total: 8.8ms	remaining: 24.2ms
# 4:	learn: 0.3520860	total: 11ms	remaining: 22ms
# 5:	learn: 0.3435847	total: 13ms	remaining: 19.4ms
# 6:	learn: 0.3383393	total: 15.1ms	remaining: 17.2ms
# 7:	learn: 0.3331612	total: 17.2ms	remaining: 15.1ms
# 8:	learn: 0.3292600	total: 19.2ms	remaining: 12.8ms
# 9:	learn: 0.3271646	total: 21ms	remaining: 10.5ms
# 10:	learn: 0.3238349	total: 22.8ms	remaining: 8.29ms
# 11:	learn: 0.3214196	total: 24.4ms	remaining: 6.09ms
# 12:	learn: 0.3206563	total: 26.2ms	remaining: 4.03ms
# 13:	learn: 0.3190962	total: 28.1ms	remaining: 2.01ms
# 14:	learn: 0.3164300	total: 30.5ms	remaining: 0us
# 0:	learn: 0.5064526	total: 2.02ms	remaining: 28.3ms
# 1:	learn: 0.4225998	total: 4.01ms	remaining: 26.1ms
# 2:	learn: 0.3885927	total: 5.46ms	remaining: 21.8ms
# 3:	learn: 0.3612283	total: 7.22ms	remaining: 19.9ms
# 4:	learn: 0.3479450	total: 8.66ms	remaining: 17.3ms
# 5:	learn: 0.3421430	total: 10.2ms	remaining: 15.4ms
# 6:	learn: 0.3341789	total: 11.8ms	remaining: 13.5ms
# 7:	learn: 0.3310859	total: 13.8ms	remaining: 12.1ms
# 8:	learn: 0.3271779	total: 16.1ms	remaining: 10.8ms
# 9:	learn: 0.3231318	total: 18.2ms	remaining: 9.09ms
# 10:	learn: 0.3194970	total: 20.2ms	remaining: 7.33ms
# 11:	learn: 0.3165262	total: 21.8ms	remaining: 5.46ms
# 12:	learn: 0.3161873	total: 23.3ms	remaining: 3.58ms
# 13:	learn: 0.3142839	total: 24.9ms	remaining: 1.78ms
# 14:	learn: 0.3131591	total: 26.4ms	remaining: 0us
# 0:	learn: 0.6772769	total: 6.28ms	remaining: 214ms
# 1:	learn: 0.6629220	total: 27.4ms	remaining: 451ms
# 2:	learn: 0.6498554	total: 30.5ms	remaining: 325ms
# 3:	learn: 0.6365216	total: 54.2ms	remaining: 420ms
# 4:	learn: 0.6235140	total: 76.3ms	remaining: 458ms
# 5:	learn: 0.6110039	total: 99.8ms	remaining: 482ms
# 6:	learn: 0.5992582	total: 122ms	remaining: 489ms
# 7:	learn: 0.5881746	total: 127ms	remaining: 430ms
# 8:	learn: 0.5777632	total: 149ms	remaining: 431ms
# 9:	learn: 0.5683419	total: 171ms	remaining: 427ms
# 10:	learn: 0.5598206	total: 192ms	remaining: 420ms
# 11:	learn: 0.5505119	total: 212ms	remaining: 406ms
# 12:	learn: 0.5413517	total: 216ms	remaining: 366ms
# 13:	learn: 0.5329500	total: 235ms	remaining: 353ms
# 14:	learn: 0.5248683	total: 255ms	remaining: 340ms
# 15:	learn: 0.5170247	total: 277ms	remaining: 329ms
# 16:	learn: 0.5099315	total: 300ms	remaining: 317ms
# 17:	learn: 0.5030516	total: 312ms	remaining: 295ms
# 18:	learn: 0.4973334	total: 314ms	remaining: 264ms
# 19:	learn: 0.4906391	total: 337ms	remaining: 253ms
# 20:	learn: 0.4847186	total: 359ms	remaining: 239ms
# 21:	learn: 0.4792580	total: 360ms	remaining: 213ms
# 22:	learn: 0.4733661	total: 382ms	remaining: 199ms
# 23:	learn: 0.4674623	total: 401ms	remaining: 184ms
# 24:	learn: 0.4620034	total: 405ms	remaining: 162ms
# 25:	learn: 0.4566812	total: 425ms	remaining: 147ms
# 26:	learn: 0.4514637	total: 431ms	remaining: 128ms
# 27:	learn: 0.4466335	total: 453ms	remaining: 113ms
# 28:	learn: 0.4420145	total: 474ms	remaining: 98.2ms
# 29:	learn: 0.4373178	total: 494ms	remaining: 82.3ms
# 30:	learn: 0.4329622	total: 518ms	remaining: 66.8ms
# 31:	learn: 0.4290559	total: 521ms	remaining: 48.8ms
# 32:	learn: 0.4247452	total: 541ms	remaining: 32.8ms
# 33:	learn: 0.4210333	total: 562ms	remaining: 16.5ms
# 34:	learn: 0.4174611	total: 568ms	remaining: 0us
# 0:	learn: 0.6775730	total: 5.49ms	remaining: 187ms
# 1:	learn: 0.6632788	total: 25.8ms	remaining: 426ms
# 2:	learn: 0.6501568	total: 28.4ms	remaining: 303ms
# 3:	learn: 0.6378722	total: 47.5ms	remaining: 368ms
# 4:	learn: 0.6249645	total: 58.5ms	remaining: 351ms
# 5:	learn: 0.6123373	total: 65.2ms	remaining: 315ms
# 6:	learn: 0.6008657	total: 72.2ms	remaining: 289ms
# 7:	learn: 0.5913258	total: 73.5ms	remaining: 248ms
# 8:	learn: 0.5808560	total: 77.1ms	remaining: 223ms
# 9:	learn: 0.5714708	total: 98.3ms	remaining: 246ms
# 10:	learn: 0.5617659	total: 120ms	remaining: 263ms
# 11:	learn: 0.5532250	total: 139ms	remaining: 267ms
# 12:	learn: 0.5443182	total: 160ms	remaining: 271ms
# 13:	learn: 0.5361454	total: 164ms	remaining: 247ms
# 14:	learn: 0.5279316	total: 186ms	remaining: 248ms
# 15:	learn: 0.5201543	total: 207ms	remaining: 245ms
# 16:	learn: 0.5128300	total: 226ms	remaining: 239ms
# 17:	learn: 0.5055098	total: 245ms	remaining: 232ms
# 18:	learn: 0.4989424	total: 263ms	remaining: 221ms
# 19:	learn: 0.4921752	total: 280ms	remaining: 210ms
# 20:	learn: 0.4860049	total: 296ms	remaining: 198ms
# 21:	learn: 0.4798792	total: 314ms	remaining: 186ms
# 22:	learn: 0.4739708	total: 332ms	remaining: 173ms
# 23:	learn: 0.4684603	total: 351ms	remaining: 161ms
# 24:	learn: 0.4629013	total: 370ms	remaining: 148ms
# 25:	learn: 0.4577375	total: 389ms	remaining: 135ms
# 26:	learn: 0.4525017	total: 406ms	remaining: 120ms
# 27:	learn: 0.4475605	total: 413ms	remaining: 103ms
# 28:	learn: 0.4426665	total: 431ms	remaining: 89.2ms
# 29:	learn: 0.4382529	total: 450ms	remaining: 75.1ms
# 30:	learn: 0.4336898	total: 470ms	remaining: 60.7ms
# 31:	learn: 0.4291624	total: 491ms	remaining: 46ms
# 32:	learn: 0.4249592	total: 513ms	remaining: 31.1ms
# 33:	learn: 0.4212225	total: 520ms	remaining: 15.3ms
# 34:	learn: 0.4175876	total: 540ms	remaining: 0us
# 0:	learn: 0.6770374	total: 6.48ms	remaining: 220ms
# 1:	learn: 0.6629879	total: 34ms	remaining: 562ms
# 2:	learn: 0.6497602	total: 36.8ms	remaining: 393ms
# 3:	learn: 0.6363959	total: 58.5ms	remaining: 454ms
# 4:	learn: 0.6232330	total: 69.2ms	remaining: 415ms
# 5:	learn: 0.6107543	total: 88.6ms	remaining: 428ms
# 6:	learn: 0.5988958	total: 111ms	remaining: 443ms
# 7:	learn: 0.5876996	total: 115ms	remaining: 388ms
# 8:	learn: 0.5776194	total: 135ms	remaining: 391ms
# 9:	learn: 0.5673598	total: 157ms	remaining: 392ms
# 10:	learn: 0.5588129	total: 176ms	remaining: 383ms
# 11:	learn: 0.5497954	total: 194ms	remaining: 371ms
# 12:	learn: 0.5407556	total: 197ms	remaining: 334ms
# 13:	learn: 0.5323030	total: 215ms	remaining: 323ms
# 14:	learn: 0.5240216	total: 237ms	remaining: 317ms
# 15:	learn: 0.5160903	total: 260ms	remaining: 309ms
# 16:	learn: 0.5088971	total: 281ms	remaining: 298ms
# 17:	learn: 0.5016750	total: 305ms	remaining: 288ms
# 18:	learn: 0.4946931	total: 325ms	remaining: 274ms
# 19:	learn: 0.4877177	total: 336ms	remaining: 252ms
# 20:	learn: 0.4811688	total: 354ms	remaining: 236ms
# 21:	learn: 0.4750544	total: 373ms	remaining: 220ms
# 22:	learn: 0.4699575	total: 376ms	remaining: 196ms
# 23:	learn: 0.4642609	total: 396ms	remaining: 182ms
# 24:	learn: 0.4589563	total: 398ms	remaining: 159ms
# 25:	learn: 0.4537092	total: 402ms	remaining: 139ms
# 26:	learn: 0.4487382	total: 423ms	remaining: 125ms
# 27:	learn: 0.4438181	total: 445ms	remaining: 111ms
# 28:	learn: 0.4387611	total: 467ms	remaining: 96.5ms
# 29:	learn: 0.4342298	total: 488ms	remaining: 81.3ms
# 30:	learn: 0.4295762	total: 510ms	remaining: 65.8ms
# 31:	learn: 0.4254833	total: 528ms	remaining: 49.5ms
# 32:	learn: 0.4214531	total: 547ms	remaining: 33.2ms
# 33:	learn: 0.4174664	total: 569ms	remaining: 16.7ms
# 34:	learn: 0.4136743	total: 589ms	remaining: 0us
# 0:	learn: 0.6784151	total: 2.83ms	remaining: 96.4ms
# 1:	learn: 0.6643921	total: 24ms	remaining: 396ms
# 2:	learn: 0.6506448	total: 43.7ms	remaining: 466ms
# 3:	learn: 0.6375920	total: 64ms	remaining: 496ms
# 4:	learn: 0.6249515	total: 87.8ms	remaining: 527ms
# 5:	learn: 0.6126859	total: 95.9ms	remaining: 463ms
# 6:	learn: 0.6010065	total: 121ms	remaining: 486ms
# 7:	learn: 0.5911885	total: 123ms	remaining: 416ms
# 8:	learn: 0.5810851	total: 128ms	remaining: 371ms
# 9:	learn: 0.5715971	total: 131ms	remaining: 327ms
# 10:	learn: 0.5617720	total: 157ms	remaining: 344ms
# 11:	learn: 0.5528988	total: 161ms	remaining: 309ms
# 12:	learn: 0.5444461	total: 187ms	remaining: 317ms
# 13:	learn: 0.5362144	total: 213ms	remaining: 319ms
# 14:	learn: 0.5287347	total: 236ms	remaining: 314ms
# 15:	learn: 0.5207241	total: 255ms	remaining: 303ms
# 16:	learn: 0.5130722	total: 262ms	remaining: 278ms
# 17:	learn: 0.5062595	total: 282ms	remaining: 267ms
# 18:	learn: 0.4999139	total: 306ms	remaining: 258ms
# 19:	learn: 0.4934559	total: 327ms	remaining: 245ms
# 20:	learn: 0.4868942	total: 349ms	remaining: 233ms
# 21:	learn: 0.4808528	total: 372ms	remaining: 220ms
# 22:	learn: 0.4749762	total: 393ms	remaining: 205ms
# 23:	learn: 0.4691402	total: 416ms	remaining: 191ms
# 24:	learn: 0.4636475	total: 438ms	remaining: 175ms
# 25:	learn: 0.4583869	total: 461ms	remaining: 160ms
# 26:	learn: 0.4534923	total: 482ms	remaining: 143ms
# 27:	learn: 0.4487032	total: 495ms	remaining: 124ms
# 28:	learn: 0.4437936	total: 517ms	remaining: 107ms
# 29:	learn: 0.4393964	total: 522ms	remaining: 87.1ms
# 30:	learn: 0.4347917	total: 546ms	remaining: 70.5ms
# 31:	learn: 0.4303727	total: 567ms	remaining: 53.2ms
# 32:	learn: 0.4268057	total: 575ms	remaining: 34.8ms
# 33:	learn: 0.4233822	total: 576ms	remaining: 17ms
# 34:	learn: 0.4195475	total: 598ms	remaining: 0us
# 0:	learn: 0.6773003	total: 5.2ms	remaining: 177ms
# 1:	learn: 0.6629791	total: 23.4ms	remaining: 386ms
# 2:	learn: 0.6492108	total: 26.9ms	remaining: 287ms
# 3:	learn: 0.6359654	total: 46ms	remaining: 356ms
# 4:	learn: 0.6227977	total: 55.3ms	remaining: 332ms
# 5:	learn: 0.6102175	total: 61.6ms	remaining: 298ms
# 6:	learn: 0.5985022	total: 68.6ms	remaining: 274ms
# 7:	learn: 0.5889658	total: 69.6ms	remaining: 235ms
# 8:	learn: 0.5786187	total: 71.6ms	remaining: 207ms
# 9:	learn: 0.5693663	total: 90.6ms	remaining: 227ms
# 10:	learn: 0.5600574	total: 93ms	remaining: 203ms
# 11:	learn: 0.5510048	total: 104ms	remaining: 199ms
# 12:	learn: 0.5419863	total: 122ms	remaining: 206ms
# 13:	learn: 0.5335514	total: 140ms	remaining: 210ms
# 14:	learn: 0.5255817	total: 142ms	remaining: 190ms
# 15:	learn: 0.5185650	total: 146ms	remaining: 173ms
# 16:	learn: 0.5110367	total: 162ms	remaining: 172ms
# 17:	learn: 0.5039074	total: 178ms	remaining: 168ms
# 18:	learn: 0.4969041	total: 192ms	remaining: 162ms
# 19:	learn: 0.4904769	total: 206ms	remaining: 155ms
# 20:	learn: 0.4838818	total: 221ms	remaining: 147ms
# 21:	learn: 0.4777733	total: 236ms	remaining: 140ms
# 22:	learn: 0.4717945	total: 251ms	remaining: 131ms
# 23:	learn: 0.4664831	total: 268ms	remaining: 123ms
# 24:	learn: 0.4610776	total: 273ms	remaining: 109ms
# 25:	learn: 0.4558157	total: 289ms	remaining: 100ms
# 26:	learn: 0.4506970	total: 304ms	remaining: 90.2ms
# 27:	learn: 0.4458884	total: 308ms	remaining: 76.9ms
# 28:	learn: 0.4414347	total: 323ms	remaining: 66.8ms
# 29:	learn: 0.4372242	total: 337ms	remaining: 56.1ms
# 30:	learn: 0.4327274	total: 350ms	remaining: 45.2ms
# 31:	learn: 0.4286702	total: 353ms	remaining: 33.1ms
# 32:	learn: 0.4247969	total: 366ms	remaining: 22.2ms
# 33:	learn: 0.4207212	total: 379ms	remaining: 11.2ms
# 34:	learn: 0.4174204	total: 381ms	remaining: 0us
# 0:	learn: 0.6711315	total: 3.92ms	remaining: 114ms
# 1:	learn: 0.6547224	total: 17.3ms	remaining: 242ms
# 2:	learn: 0.6344794	total: 18.9ms	remaining: 170ms
# 3:	learn: 0.6187415	total: 31.8ms	remaining: 207ms
# 4:	learn: 0.6023923	total: 39.3ms	remaining: 197ms
# 5:	learn: 0.5883124	total: 53ms	remaining: 212ms
# 6:	learn: 0.5748806	total: 67.8ms	remaining: 223ms
# 7:	learn: 0.5609019	total: 70.9ms	remaining: 195ms
# 8:	learn: 0.5501523	total: 85.3ms	remaining: 199ms
# 9:	learn: 0.5423933	total: 99.5ms	remaining: 199ms
# 10:	learn: 0.5346286	total: 113ms	remaining: 196ms
# 11:	learn: 0.5248892	total: 128ms	remaining: 191ms
# 12:	learn: 0.5137272	total: 131ms	remaining: 171ms
# 13:	learn: 0.5057483	total: 144ms	remaining: 165ms
# 14:	learn: 0.4985323	total: 158ms	remaining: 158ms
# 15:	learn: 0.4904636	total: 171ms	remaining: 150ms
# 16:	learn: 0.4850686	total: 185ms	remaining: 141ms
# 17:	learn: 0.4772569	total: 199ms	remaining: 132ms
# 18:	learn: 0.4701835	total: 214ms	remaining: 124ms
# 19:	learn: 0.4622860	total: 215ms	remaining: 108ms
# 20:	learn: 0.4570391	total: 229ms	remaining: 98.3ms
# 21:	learn: 0.4518911	total: 244ms	remaining: 88.8ms
# 22:	learn: 0.4468599	total: 260ms	remaining: 79.1ms
# 23:	learn: 0.4418117	total: 276ms	remaining: 69.1ms
# 24:	learn: 0.4358113	total: 278ms	remaining: 55.7ms
# 25:	learn: 0.4307597	total: 282ms	remaining: 43.4ms
# 26:	learn: 0.4269174	total: 298ms	remaining: 33.1ms
# 27:	learn: 0.4227565	total: 307ms	remaining: 21.9ms
# 28:	learn: 0.4187078	total: 322ms	remaining: 11.1ms
# 29:	learn: 0.4146227	total: 337ms	remaining: 0us
# 0:	learn: 0.6721255	total: 4.3ms	remaining: 125ms
# 1:	learn: 0.6569588	total: 16.7ms	remaining: 233ms
# 2:	learn: 0.6369620	total: 18.4ms	remaining: 165ms
# 3:	learn: 0.6217767	total: 31.4ms	remaining: 204ms
# 4:	learn: 0.6050247	total: 36.2ms	remaining: 181ms
# 5:	learn: 0.5891222	total: 45.1ms	remaining: 181ms
# 6:	learn: 0.5751460	total: 51.7ms	remaining: 170ms
# 7:	learn: 0.5615332	total: 53.1ms	remaining: 146ms
# 8:	learn: 0.5478301	total: 55.7ms	remaining: 130ms
# 9:	learn: 0.5380675	total: 75.4ms	remaining: 151ms
# 10:	learn: 0.5264500	total: 78.2ms	remaining: 135ms
# 11:	learn: 0.5168518	total: 88.8ms	remaining: 133ms
# 12:	learn: 0.5078607	total: 108ms	remaining: 142ms
# 13:	learn: 0.4999737	total: 125ms	remaining: 143ms
# 14:	learn: 0.4906686	total: 127ms	remaining: 127ms
# 15:	learn: 0.4837242	total: 143ms	remaining: 125ms
# 16:	learn: 0.4781417	total: 159ms	remaining: 122ms
# 17:	learn: 0.4704194	total: 163ms	remaining: 108ms
# 18:	learn: 0.4644426	total: 179ms	remaining: 104ms
# 19:	learn: 0.4583529	total: 193ms	remaining: 96.5ms
# 20:	learn: 0.4517998	total: 196ms	remaining: 84.1ms
# 21:	learn: 0.4474172	total: 212ms	remaining: 77.3ms
# 22:	learn: 0.4430024	total: 228ms	remaining: 69.3ms
# 23:	learn: 0.4384450	total: 244ms	remaining: 61ms
# 24:	learn: 0.4334950	total: 256ms	remaining: 51.2ms
# 25:	learn: 0.4299513	total: 274ms	remaining: 42.1ms
# 26:	learn: 0.4247090	total: 278ms	remaining: 30.9ms
# 27:	learn: 0.4199844	total: 282ms	remaining: 20.2ms
# 28:	learn: 0.4172861	total: 300ms	remaining: 10.4ms
# 29:	learn: 0.4140587	total: 318ms	remaining: 0us
# 0:	learn: 0.6708355	total: 3.55ms	remaining: 103ms
# 1:	learn: 0.6555147	total: 16.7ms	remaining: 234ms
# 2:	learn: 0.6353853	total: 18.6ms	remaining: 168ms
# 3:	learn: 0.6192930	total: 32ms	remaining: 208ms
# 4:	learn: 0.6023987	total: 36.4ms	remaining: 182ms
# 5:	learn: 0.5863660	total: 44.6ms	remaining: 179ms
# 6:	learn: 0.5723655	total: 49.3ms	remaining: 162ms
# 7:	learn: 0.5587920	total: 50.1ms	remaining: 138ms
# 8:	learn: 0.5448795	total: 52ms	remaining: 121ms
# 9:	learn: 0.5365390	total: 67.7ms	remaining: 135ms
# 10:	learn: 0.5241968	total: 69.4ms	remaining: 120ms
# 11:	learn: 0.5140921	total: 78.7ms	remaining: 118ms
# 12:	learn: 0.5052748	total: 95.1ms	remaining: 124ms
# 13:	learn: 0.4962750	total: 112ms	remaining: 128ms
# 14:	learn: 0.4868872	total: 114ms	remaining: 114ms
# 15:	learn: 0.4798738	total: 130ms	remaining: 114ms
# 16:	learn: 0.4743020	total: 145ms	remaining: 111ms
# 17:	learn: 0.4671465	total: 153ms	remaining: 102ms
# 18:	learn: 0.4599012	total: 155ms	remaining: 89.7ms
# 19:	learn: 0.4541904	total: 169ms	remaining: 84.3ms
# 20:	learn: 0.4476043	total: 173ms	remaining: 74.3ms
# 21:	learn: 0.4420961	total: 187ms	remaining: 68.1ms
# 22:	learn: 0.4362359	total: 192ms	remaining: 58.4ms
# 23:	learn: 0.4309347	total: 199ms	remaining: 49.8ms
# 24:	learn: 0.4262389	total: 212ms	remaining: 42.4ms
# 25:	learn: 0.4227935	total: 226ms	remaining: 34.8ms
# 26:	learn: 0.4183488	total: 241ms	remaining: 26.8ms
# 27:	learn: 0.4147808	total: 257ms	remaining: 18.4ms
# 28:	learn: 0.4116441	total: 274ms	remaining: 9.44ms
# 29:	learn: 0.4081112	total: 289ms	remaining: 0us
# 0:	learn: 0.6706254	total: 1.54ms	remaining: 44.8ms
# 1:	learn: 0.6523540	total: 14ms	remaining: 196ms
# 2:	learn: 0.6373309	total: 26.7ms	remaining: 240ms
# 3:	learn: 0.6222622	total: 40.5ms	remaining: 263ms
# 4:	learn: 0.6077737	total: 56.4ms	remaining: 282ms
# 5:	learn: 0.5941724	total: 72.6ms	remaining: 290ms
# 6:	learn: 0.5823866	total: 88.9ms	remaining: 292ms
# 7:	learn: 0.5712196	total: 106ms	remaining: 291ms
# 8:	learn: 0.5585658	total: 122ms	remaining: 284ms
# 9:	learn: 0.5475250	total: 131ms	remaining: 262ms
# 10:	learn: 0.5375359	total: 146ms	remaining: 252ms
# 11:	learn: 0.5273058	total: 160ms	remaining: 239ms
# 12:	learn: 0.5168781	total: 164ms	remaining: 215ms
# 13:	learn: 0.5095358	total: 178ms	remaining: 204ms
# 14:	learn: 0.5029128	total: 191ms	remaining: 191ms
# 15:	learn: 0.4927297	total: 193ms	remaining: 169ms
# 16:	learn: 0.4855552	total: 207ms	remaining: 158ms
# 17:	learn: 0.4781983	total: 220ms	remaining: 147ms
# 18:	learn: 0.4706028	total: 234ms	remaining: 135ms
# 19:	learn: 0.4638289	total: 248ms	remaining: 124ms
# 20:	learn: 0.4580419	total: 263ms	remaining: 113ms
# 21:	learn: 0.4516122	total: 279ms	remaining: 102ms
# 22:	learn: 0.4463677	total: 295ms	remaining: 89.9ms
# 23:	learn: 0.4419094	total: 313ms	remaining: 78.3ms
# 24:	learn: 0.4364259	total: 318ms	remaining: 63.7ms
# 25:	learn: 0.4326657	total: 333ms	remaining: 51.3ms
# 26:	learn: 0.4284503	total: 348ms	remaining: 38.6ms
# 27:	learn: 0.4252742	total: 362ms	remaining: 25.8ms
# 28:	learn: 0.4218731	total: 376ms	remaining: 13ms
# 29:	learn: 0.4183810	total: 391ms	remaining: 0us
# 0:	learn: 0.6719441	total: 6.1ms	remaining: 177ms
# 1:	learn: 0.6533966	total: 22.6ms	remaining: 316ms
# 2:	learn: 0.6334041	total: 25.2ms	remaining: 227ms
# 3:	learn: 0.6175797	total: 43.9ms	remaining: 285ms
# 4:	learn: 0.6009901	total: 49.9ms	remaining: 250ms
# 5:	learn: 0.5864656	total: 70.9ms	remaining: 284ms
# 6:	learn: 0.5743830	total: 90.1ms	remaining: 296ms
# 7:	learn: 0.5623620	total: 108ms	remaining: 296ms
# 8:	learn: 0.5515413	total: 124ms	remaining: 289ms
# 9:	learn: 0.5415018	total: 141ms	remaining: 282ms
# 10:	learn: 0.5328471	total: 158ms	remaining: 273ms
# 11:	learn: 0.5219862	total: 173ms	remaining: 259ms
# 12:	learn: 0.5109690	total: 175ms	remaining: 229ms
# 13:	learn: 0.5016893	total: 178ms	remaining: 203ms
# 14:	learn: 0.4935666	total: 193ms	remaining: 193ms
# 15:	learn: 0.4863871	total: 209ms	remaining: 182ms
# 16:	learn: 0.4796596	total: 225ms	remaining: 172ms
# 17:	learn: 0.4735059	total: 240ms	remaining: 160ms
# 18:	learn: 0.4667127	total: 256ms	remaining: 148ms
# 19:	learn: 0.4603223	total: 271ms	remaining: 136ms
# 20:	learn: 0.4544240	total: 287ms	remaining: 123ms
# 21:	learn: 0.4476551	total: 289ms	remaining: 105ms
# 22:	learn: 0.4410897	total: 292ms	remaining: 89ms
# 23:	learn: 0.4368811	total: 306ms	remaining: 76.6ms
# 24:	learn: 0.4316747	total: 315ms	remaining: 62.9ms
# 25:	learn: 0.4261385	total: 317ms	remaining: 48.8ms
# 26:	learn: 0.4231319	total: 332ms	remaining: 36.9ms
# 27:	learn: 0.4197525	total: 346ms	remaining: 24.7ms
# 28:	learn: 0.4151824	total: 349ms	remaining: 12ms
# 29:	learn: 0.4109452	total: 353ms	remaining: 0us
# 0:	learn: 0.6885493	total: 1.71ms	remaining: 24ms
# 1:	learn: 0.6841494	total: 3.62ms	remaining: 23.6ms
# 2:	learn: 0.6795503	total: 5.09ms	remaining: 20.4ms
# 3:	learn: 0.6747968	total: 6.59ms	remaining: 18.1ms
# 4:	learn: 0.6701341	total: 8.07ms	remaining: 16.1ms
# 5:	learn: 0.6655934	total: 9.98ms	remaining: 15ms
# 6:	learn: 0.6616811	total: 11.6ms	remaining: 13.2ms
# 7:	learn: 0.6577158	total: 13.2ms	remaining: 11.5ms
# 8:	learn: 0.6534475	total: 14.2ms	remaining: 9.45ms
# 9:	learn: 0.6492111	total: 15.7ms	remaining: 7.84ms
# ...
# 8:	learn: 0.5808560	total: 56.3ms	remaining: 68.8ms
# 9:	learn: 0.5714708	total: 71.6ms	remaining: 71.6ms
# 10:	learn: 0.5617659	total: 91.7ms	remaining: 75ms
# 11:	learn: 0.5532250	total: 111ms	remaining: 73.7ms
# 12:	learn: 0.5443182	total: 130ms	remaining: 69.9ms
# 13:	learn: 0.5361454	total: 134ms	remaining: 57.5ms
# 14:	learn: 0.5279316	total: 153ms	remaining: 51ms
# 15:	learn: 0.5201543	total: 170ms	remaining: 42.4ms
# 16:	learn: 0.5128300	total: 186ms	remaining: 32.8ms
# 17:	learn: 0.5055098	total: 202ms	remaining: 22.4ms
# 18:	learn: 0.4989424	total: 216ms	remaining: 11.4ms
# 19:	learn: 0.4921752	total: 230ms	remaining: 0us
# 0:	learn: 0.6770374	total: 5.06ms	remaining: 96.2ms
# 1:	learn: 0.6629879	total: 21.5ms	remaining: 194ms
# 2:	learn: 0.6497602	total: 23.9ms	remaining: 135ms
# 3:	learn: 0.6363959	total: 41.8ms	remaining: 167ms
# 4:	learn: 0.6232330	total: 51.7ms	remaining: 155ms
# 5:	learn: 0.6107543	total: 70.3ms	remaining: 164ms
# 6:	learn: 0.5988958	total: 88.3ms	remaining: 164ms
# 7:	learn: 0.5876996	total: 94ms	remaining: 141ms
# 8:	learn: 0.5776194	total: 110ms	remaining: 135ms
# 9:	learn: 0.5673598	total: 125ms	remaining: 125ms
# 10:	learn: 0.5588129	total: 140ms	remaining: 115ms
# 11:	learn: 0.5497954	total: 154ms	remaining: 103ms
# 12:	learn: 0.5407556	total: 157ms	remaining: 84.5ms
# 13:	learn: 0.5323030	total: 170ms	remaining: 72.9ms
# 14:	learn: 0.5240216	total: 183ms	remaining: 61ms
# 15:	learn: 0.5160903	total: 197ms	remaining: 49.3ms
# 16:	learn: 0.5088971	total: 213ms	remaining: 37.5ms
# 17:	learn: 0.5016750	total: 232ms	remaining: 25.8ms
# 18:	learn: 0.4946931	total: 251ms	remaining: 13.2ms
# 19:	learn: 0.4877177	total: 262ms	remaining: 0us
# 0:	learn: 0.6784151	total: 1.56ms	remaining: 29.7ms
# 1:	learn: 0.6643921	total: 14.2ms	remaining: 128ms
# 2:	learn: 0.6506448	total: 27.7ms	remaining: 157ms
# 3:	learn: 0.6375920	total: 42.9ms	remaining: 172ms
# 4:	learn: 0.6249515	total: 59ms	remaining: 177ms
# 5:	learn: 0.6126859	total: 65.3ms	remaining: 152ms
# 6:	learn: 0.6010065	total: 86.3ms	remaining: 160ms
# 7:	learn: 0.5911885	total: 88.1ms	remaining: 132ms
# 8:	learn: 0.5810851	total: 93ms	remaining: 114ms
# 9:	learn: 0.5715971	total: 96.1ms	remaining: 96.1ms
# 10:	learn: 0.5617720	total: 123ms	remaining: 101ms
# 11:	learn: 0.5528988	total: 128ms	remaining: 85ms
# 12:	learn: 0.5444461	total: 149ms	remaining: 80.5ms
# 13:	learn: 0.5362144	total: 171ms	remaining: 73.3ms
# 14:	learn: 0.5287347	total: 191ms	remaining: 63.6ms
# 15:	learn: 0.5207241	total: 210ms	remaining: 52.4ms
# 16:	learn: 0.5130722	total: 216ms	remaining: 38.1ms
# 17:	learn: 0.5062595	total: 234ms	remaining: 26ms
# 18:	learn: 0.4999139	total: 254ms	remaining: 13.4ms
# 19:	learn: 0.4934559	total: 273ms	remaining: 0us
# 0:	learn: 0.6773003	total: 5.68ms	remaining: 108ms
# 1:	learn: 0.6629791	total: 23.2ms	remaining: 209ms
# 2:	learn: 0.6492108	total: 26ms	remaining: 147ms
# 3:	learn: 0.6359654	total: 44.7ms	remaining: 179ms
# 4:	learn: 0.6227977	total: 57.2ms	remaining: 172ms
# 5:	learn: 0.6102175	total: 63.3ms	remaining: 148ms
# 6:	learn: 0.5985022	total: 69.3ms	remaining: 129ms
# 7:	learn: 0.5889658	total: 70.8ms	remaining: 106ms
# 8:	learn: 0.5786187	total: 73.1ms	remaining: 89.4ms
# 9:	learn: 0.5693663	total: 96.2ms	remaining: 96.2ms
# 10:	learn: 0.5600574	total: 98.9ms	remaining: 80.9ms
# 11:	learn: 0.5510048	total: 111ms	remaining: 74ms
# 12:	learn: 0.5419863	total: 130ms	remaining: 70.1ms
# 13:	learn: 0.5335514	total: 152ms	remaining: 65.1ms
# 14:	learn: 0.5255817	total: 155ms	remaining: 51.8ms
# 15:	learn: 0.5185650	total: 159ms	remaining: 39.8ms
# 16:	learn: 0.5110367	total: 179ms	remaining: 31.5ms
# 17:	learn: 0.5039074	total: 197ms	remaining: 21.9ms
# 18:	learn: 0.4969041	total: 215ms	remaining: 11.3ms
# 19:	learn: 0.4904769	total: 234ms	remaining: 0us
# 0:	learn: 0.6886671	total: 5.4ms	remaining: 21.6ms
# 1:	learn: 0.6851194	total: 21.7ms	remaining: 32.5ms
# 2:	learn: 0.6806882	total: 23.9ms	remaining: 15.9ms
# 3:	learn: 0.6783154	total: 23.9ms	remaining: 15.9ms
# 4:	learn: 0.6743143	total: 30.5ms	remaining: 0us
# 0:	learn: 0.6888713	total: 5.77ms	remaining: 23.1ms
# 1:	learn: 0.6859725	total: 75.3ms	remaining: 113ms
# 2:	learn: 0.6832479	total: 828ms	remaining: 552ms
# 3:	learn: 0.6788048	total: 831ms	remaining: 208ms
# 4:	learn: 0.6764273	total: 1.55s	remaining: 0us
# 0:	learn: 0.6886049	total: 3.86ms	remaining: 15.5ms
# 1:	learn: 0.6856472	total: 53.2ms	remaining: 79.8ms
# 2:	learn: 0.6829464	total: 855ms	remaining: 570ms
# 3:	learn: 0.6784747	total: 859ms	remaining: 215ms
# 4:	learn: 0.6742457	total: 875ms	remaining: 0us
# 0:	learn: 0.6885541	total: 2.38ms	remaining: 9.54ms
# 1:	learn: 0.6860375	total: 2.38ms	remaining: 9.54ms
# 2:	learn: 0.6832317	total: 2.38ms	remaining: 9.54ms
# 3:	learn: 0.6786792	total: 5.33ms	remaining: 2.66ms
# 4:	learn: 0.6749416	total: 29.1ms	remaining: 0us
# 0:	learn: 0.6888333	total: 4.58ms	remaining: 18.3ms
# 1:	learn: 0.6859439	total: 62.3ms	remaining: 93.5ms
# 2:	learn: 0.6831823	total: 955ms	remaining: 637ms
# 3:	learn: 0.6786248	total: 958ms	remaining: 240ms
# 4:	learn: 0.6762368	total: 1.8s	remaining: 0us
# 0:	learn: 0.4675192	total: 4.25ms	remaining: 38.2ms
# 1:	learn: 0.4083214	total: 17.7ms	remaining: 70.9ms
# 2:	learn: 0.3712318	total: 19.8ms	remaining: 46.3ms
# 3:	learn: 0.3491885	total: 33.5ms	remaining: 50.3ms
# 4:	learn: 0.3360914	total: 47.6ms	remaining: 47.6ms
# 5:	learn: 0.3232670	total: 62.1ms	remaining: 41.4ms
# 6:	learn: 0.3140673	total: 78ms	remaining: 33.4ms
# 7:	learn: 0.3065814	total: 93.1ms	remaining: 23.3ms
# 8:	learn: 0.3008835	total: 108ms	remaining: 12ms
# 9:	learn: 0.2947482	total: 123ms	remaining: 0us
# 0:	learn: 0.4750068	total: 4.49ms	remaining: 40.4ms
# 1:	learn: 0.4098906	total: 17.1ms	remaining: 68.5ms
# 2:	learn: 0.3697691	total: 18.8ms	remaining: 43.8ms
# 3:	learn: 0.3498839	total: 31.4ms	remaining: 47.2ms
# 4:	learn: 0.3380433	total: 44.9ms	remaining: 44.9ms
# 5:	learn: 0.3297090	total: 47.7ms	remaining: 31.8ms
# 6:	learn: 0.3205701	total: 61.6ms	remaining: 26.4ms
# 7:	learn: 0.3130003	total: 77.4ms	remaining: 19.4ms
# 8:	learn: 0.3070167	total: 95ms	remaining: 10.6ms
# 9:	learn: 0.3000435	total: 113ms	remaining: 0us
# 0:	learn: 0.4639498	total: 4.12ms	remaining: 37.1ms
# 1:	learn: 0.3967985	total: 17.2ms	remaining: 68.9ms
# 2:	learn: 0.3633572	total: 19.2ms	remaining: 44.9ms
# 3:	learn: 0.3442412	total: 34.8ms	remaining: 52.1ms
# 4:	learn: 0.3304682	total: 43.3ms	remaining: 43.3ms
# 5:	learn: 0.3200545	total: 58.6ms	remaining: 39.1ms
# 6:	learn: 0.3113443	total: 74.6ms	remaining: 32ms
# 7:	learn: 0.3037064	total: 91.9ms	remaining: 23ms
# 8:	learn: 0.2972459	total: 111ms	remaining: 12.3ms
# 9:	learn: 0.2908519	total: 130ms	remaining: 0us
# 0:	learn: 0.4701232	total: 2.17ms	remaining: 19.5ms
# 1:	learn: 0.4059147	total: 15.3ms	remaining: 61.4ms
# 2:	learn: 0.3722627	total: 28.7ms	remaining: 67ms
# 3:	learn: 0.3520007	total: 43.7ms	remaining: 65.6ms
# 4:	learn: 0.3375322	total: 61ms	remaining: 61ms
# 5:	learn: 0.3267222	total: 79.5ms	remaining: 53ms
# 6:	learn: 0.3176237	total: 98.7ms	remaining: 42.3ms
# 7:	learn: 0.3098815	total: 120ms	remaining: 30.1ms
# 8:	learn: 0.3034508	total: 144ms	remaining: 16ms
# 9:	learn: 0.2966758	total: 165ms	remaining: 0us
# 0:	learn: 0.4734022	total: 3.78ms	remaining: 34.1ms
# 1:	learn: 0.4014717	total: 16.6ms	remaining: 66.5ms
# 2:	learn: 0.3668024	total: 18.4ms	remaining: 42.9ms
# 3:	learn: 0.3464619	total: 34.7ms	remaining: 52.1ms
# 4:	learn: 0.3354622	total: 50.7ms	remaining: 50.7ms
# 5:	learn: 0.3255674	total: 69.2ms	remaining: 46.1ms
# 6:	learn: 0.3180380	total: 90.6ms	remaining: 38.8ms
# 7:	learn: 0.3105527	total: 115ms	remaining: 28.6ms
# 8:	learn: 0.3038893	total: 135ms	remaining: 15ms
# 9:	learn: 0.2965337	total: 156ms	remaining: 0us
# /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 160 fits failed out of a total of 750.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/imblearn/pipeline.py", line 297, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/catboost/core.py", line 5128, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/catboost/core.py", line 2339, in _fit
#     train_params = self._prepare_train_params(
#   File "/Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/catboost/core.py", line 2266, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6080, in _catboost._check_train_params
#   File "_catboost.pyx", line 6099, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:125: Maximum tree depth is 16
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/renatapyatkova/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.81375217 0.80906783 0.81472767 0.80964911 0.8048691
#  0.7989941  0.82356917 0.82628991 0.81864789 0.80619669 0.80186022
#  0.79369357        nan 0.79237789 0.80523595 0.80895658 0.80409154
#  0.8044972  0.79916928 0.8047065  0.82368098 0.80753844 0.85767324
#  0.80269776        nan 0.80376771 0.79455703 0.82604781 0.7933103
#  0.80583487 0.81695313        nan 0.79898886        nan        nan
#  0.83256201 0.79099166        nan        nan 0.79844013        nan
#  0.81299233        nan        nan 0.78930341 0.8136147  0.83297503
#  0.79979529 0.81714913 0.79528177 0.79562694        nan 0.79727442
#  0.80152755 0.82799033 0.79392531        nan 0.83649115 0.80095678
#  0.80299635 0.79880167 0.82448935 0.81446691 0.81683317 0.79103005
#  0.79685899 0.82071511 0.84179326 0.80278638 0.78987342 0.85359863
#  0.81921874 0.81336365        nan 0.81761836 0.80628042 0.82477221
#  0.79807532 0.82752089 0.8398348  0.81017674 0.8251163         nan
#  0.82956454 0.80247806        nan        nan 0.82719097 0.81927141
#  0.78878668 0.81186426 0.81073447        nan        nan 0.81616805
#  0.79555148 0.79421559 0.80892568 0.78535026 0.83229692 0.81528827
#         nan 0.8003995  0.83904064 0.79411683 0.80102683        nan
#         nan 0.82015561 0.80541759 0.81555184        nan 0.82266067
#  0.82332915        nan 0.84501617 0.80103241 0.82267366 0.8055687
#  0.82195083 0.81194029 0.80994828        nan 0.79848194 0.83240734
#         nan        nan 0.81344019 0.81830484 0.7898042  0.82531163
#  0.80487095 0.81018925        nan        nan 0.80153567 0.83300443
#         nan 0.80897021 0.82325976 0.81472262        nan 0.82593744
#  0.80887368 0.80051405 0.81515253        nan 0.78297422 0.81078292]
#   warnings.warn(
# 0:	learn: 0.5012764	total: 2.47ms	remaining: 96.4ms
# 1:	learn: 0.4198189	total: 5.83ms	remaining: 111ms
# 2:	learn: 0.3754305	total: 8.32ms	remaining: 103ms
# 3:	learn: 0.3530559	total: 10.7ms	remaining: 96.3ms
# 4:	learn: 0.3414512	total: 13.7ms	remaining: 96.1ms
# 5:	learn: 0.3344829	total: 16.3ms	remaining: 92.6ms
# 6:	learn: 0.3280794	total: 19ms	remaining: 89.7ms
# 7:	learn: 0.3207405	total: 21.7ms	remaining: 86.9ms
# 8:	learn: 0.3160194	total: 24.7ms	remaining: 85ms
# 9:	learn: 0.3126181	total: 27.5ms	remaining: 82.4ms
# 10:	learn: 0.3103841	total: 30.6ms	remaining: 80.5ms
# 11:	learn: 0.3081805	total: 33.3ms	remaining: 77.7ms
# 12:	learn: 0.3045000	total: 36ms	remaining: 74.9ms
# 13:	learn: 0.3023694	total: 38.6ms	remaining: 71.8ms
# 14:	learn: 0.2992785	total: 41.5ms	remaining: 69.2ms
# 15:	learn: 0.2956978	total: 44.8ms	remaining: 67.1ms
# 16:	learn: 0.2923420	total: 47.9ms	remaining: 64.8ms
# 17:	learn: 0.2905028	total: 51.1ms	remaining: 62.5ms
# 18:	learn: 0.2874502	total: 53.8ms	remaining: 59.5ms
# 19:	learn: 0.2863298	total: 57.2ms	remaining: 57.2ms
# 20:	learn: 0.2843035	total: 60ms	remaining: 54.2ms
# 21:	learn: 0.2796097	total: 63ms	remaining: 51.6ms
# 22:	learn: 0.2783083	total: 66.6ms	remaining: 49.2ms
# 23:	learn: 0.2769491	total: 69.4ms	remaining: 46.3ms
# 24:	learn: 0.2751619	total: 72.9ms	remaining: 43.8ms
# 25:	learn: 0.2706945	total: 76.3ms	remaining: 41.1ms
# 26:	learn: 0.2685624	total: 79.3ms	remaining: 38.2ms
# 27:	learn: 0.2667205	total: 84.1ms	remaining: 36.1ms
# 28:	learn: 0.2610843	total: 87.5ms	remaining: 33.2ms
# 29:	learn: 0.2571571	total: 90.6ms	remaining: 30.2ms
# 30:	learn: 0.2541267	total: 93.6ms	remaining: 27.2ms
# 31:	learn: 0.2519734	total: 97ms	remaining: 24.2ms
# 32:	learn: 0.2488032	total: 100ms	remaining: 21.2ms
# 33:	learn: 0.2466848	total: 104ms	remaining: 18.3ms
# 34:	learn: 0.2443776	total: 107ms	remaining: 15.3ms
# 35:	learn: 0.2410082	total: 111ms	remaining: 12.3ms
# 36:	learn: 0.2372873	total: 114ms	remaining: 9.24ms
# 37:	learn: 0.2351804	total: 117ms	remaining: 6.17ms
# 38:	learn: 0.2341824	total: 120ms	remaining: 3.08ms
# 39:	learn: 0.2302052	total: 123ms	remaining: 0us
# CPU times: user 43min 31s, sys: 17min 35s, total: 1h 1min 7s
# Wall time: 22min 40s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(transformers=[('num_cols',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['MonthlyCharges',
#                                                                                 'TotalCharges',
#                                                                                 'DurationContract_x']),
#                                                                               ('category_encoder',
#                                                                                OrdinalEncoder(),
#                                                                                ['SeniorCitizen',
#                                                                                 'Partner',
#                                                                                 'Dependents',
#                                                                                 'Type',
#                                                                                 'PaperlessBilling',
#                                                                                 'PaymentMethod',
#                                                                                 'InternetServi...
#                                                                                 'TechSupport',
#                                                                                 'StreamingTV',
#                                                                                 'StreamingMovies',
#                                                                                 'MultipleLines'])])),
#                                              ('mod',
#                                               <catboost.core.CatBoostClassifier object at 0x7fc7c439c5e0>)]),
#                    n_iter=150,
#                    param_distributions=[{'mod__depth': [4, 6, 10, 15, 20],
#                                          'mod__l2_leaf_reg': [1, 3, 5, 7, 9],
#                                          'mod__learning_rate': [0.01, 0.03,
#                                                                 0.05, 0.1, 0.5,
#                                                                 0.7],
#                                          'mod__n_estimators': range(5, 50, 5)}],
#                    random_state=240423, scoring='roc_auc')

# %%
model_CB = grid_CB.best_estimator_
model_CB
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_cols',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'DurationContract_x']),
#                                                  ('category_encoder',
#                                                   OrdinalEncoder(),
#                                                   ['SeniorCitizen', 'Partner',
#                                                    'Dependents', 'Type',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'MultipleLines'])])),
#                 ('mod',
#                  <catboost.core.CatBoostClassifier object at 0x7fc7c5bf83a0>)])

# %%
grid_CB.best_score_
# Out:
# 0.8576732363341751

# %%
grid_res = pd.DataFrame(grid_CB.cv_results_).sort_values(by='rank_test_score')

# %%
grid_res.iloc[0]['mean_fit_time'], grid_res.iloc[0]['mean_score_time']
# Out:
# (0.17981843948364257, 0.02567734718322754)

# %%
CB_fit_time = grid_res.iloc[0]['mean_fit_time']
CB_score_time = grid_res.iloc[0]['mean_score_time']

# %%
pipeline.steps.pop(1)
# Out:
# ('mod', <catboost.core.CatBoostClassifier at 0x7fc7c439c5e0>)

# %%
d = {"score":pd.Series([grid_LR.best_score_, grid_RF.best_score_, grid_CB.best_score_], index=['LR', 'RF', 'CB']),
   ...: "FitTime": pd.Series([LR_fit_time,RF_fit_time,CB_fit_time], index=['LR', 'RF', 'CB']),
   ...: 'ScoreTime': pd.Series([LR_score_time,RF_score_time,CB_score_time], index=['LR', 'RF', 'CB'])}
df1 = pd.DataFrame(d)
display(df1)
# Out:
#        score   FitTime  ScoreTime
# LR  0.755277  0.211976   0.076001
# RF  0.830036  6.016023   0.269944
# CB  0.857673  0.179818   0.025677

# %% [markdown]
# Лучшая модель   **CatboostClassifier**

# %% [markdown]
# ### Проверка на тестовой выборке

# %%
predictions = model_CB.predict_proba(X_test)

# %%
predictions
# Out:
# array([[0.96734708, 0.03265292],
#        [0.99255984, 0.00744016],
#        [0.74377939, 0.25622061],
#        ...,
#        [0.96711587, 0.03288413],
#        [0.85333662, 0.14666338],
#        [0.72547508, 0.27452492]])

# %%
metrics = roc_auc_score(y_test, predictions[:,1])
metrics
# Out:
# 0.8736060184599823

# %%
imp = pd.Series(grid_CB.best_estimator_.named_steps['mod'].feature_importances_, index=grid_CB.best_estimator_.named_steps['columntransformer'].get_feature_names_out())
imp
# Out:
# num_cols__MonthlyCharges               7.904482
# num_cols__TotalCharges                 7.271179
# num_cols__DurationContract_x          41.638027
# category_encoder__SeniorCitizen        1.722239
# category_encoder__Partner              3.801174
# category_encoder__Dependents           1.287255
# category_encoder__Type                13.687798
# category_encoder__PaperlessBilling     1.318432
# category_encoder__PaymentMethod        5.036530
# category_encoder__InternetService      1.421981
# category_encoder__OnlineSecurity       0.404844
# category_encoder__OnlineBackup         3.065783
# category_encoder__DeviceProtection     2.805745
# category_encoder__TechSupport          1.313788
# category_encoder__StreamingTV          1.139138
# category_encoder__StreamingMovies      2.414734
# category_encoder__MultipleLines        3.766871
# dtype: float64

# %%
plt.title('Importance of features')

plt.ylabel('Features', fontsize=12)
imp.nlargest(20).plot(kind='barh', figsize = (9,4));
plt.xlabel('Importance')
# Out:
# Text(0.5, 0, 'Importance')

# %% [markdown]
# Сильная зависимость присутсвует между длительностью контракта и уходом клиента. Как мы и предположили в начале, признак Type оказался действительно важным для опредления лояльности клиента. Также достаточно важно, какую сумму платит клиент ежемесячно. Имеют значению такие признаки как наличие партнера и метод оплаты услуг.

# %%
pred = model_CB.predict(X_test)

# %%
conf_m = confusion_matrix(y_test, pred)
conf_m
# Out:
# array([[1391,   47],
#        [ 164,  111]])

# %%
plt.figure(figsize=(10,8))
mp = sns.heatmap(conf_m, annot=True, cmap="turbo")

mp.set_title('ConfusionMatrix',fontsize=(15));
mp.set_xlabel('Predictions', fontsize=(15));
mp.set_ylabel('Reality',fontsize=(15));

mp.xaxis.set_ticklabels(['False', 'True']);
mp.yaxis.set_ticklabels(['False', 'True']);

# %% [markdown]
# Наша модель успешно предсказывает истинно отрицательные результаты, т.е. случай, когда клиент продолжает оплачивать услуги и пользоваться ими. Истинно положительных ответов больше чем ложно положительных, т.е. модель вполне справляется с предсказыванием ухода клиента от компании. Случаев положительных гораздо меньше в выборке, с эти и связана не идельная точность модели

# %% [markdown]
# ## Отчет

# %% [markdown]
# - Какие пункты плана были выполнены, а какие — нет. Почему?
#
# *Выполнены все пункты плана*
#
# - Какие трудности возникли и как вы их преодолели?
#
# *Было достаточно сложно достигнуть хорошей метрики (больше 0.85), поскольку сначала я удалила некоторые из кореллирующих между собой признаков (те, чей коэффицент корелляции был больше 0.6), но этого делать не стоило, тк чем меньше признаков, тем сложнее модели обучаться, тем более что все-таки 0.6 можно считать не супер высоким коэффицентом.*
#
# *Также столкнулась с недостатком оперативной памяти моего компьютера, поскольку в планах было использовать бустинговую модель LightGBM, но ядро не выдерживало и умирало. Не считаю это огромной потерей, поскольку удалось воспользоваться другой бустинговой моделью Catboost, которая по качеству и скорости предсказаний почти не отличается.*
#
#
# - Какие ключевые шаги в решении задачи вы выделили?
#
# *Самыми важными этапами я считаю **предобработку данных**, т.е. приведение данных у нужному типу, обьеденение датафреймов, создание допольнительных признаков. Далее, **построение пайплайна и обучение моделей**. Поскольку подбор гиперпарамтеров я делала через GridSearchCV, то пайплайн был необходим,тк в случае его отсуствия происходила бы утечка данных из train  в test, и я не смогла бы выбрать лучшие параметры и модель. В финале работы неоходимо было **протестировтаь выбранную лучшую модель на тестовых данных**, чтобы получить окончательную метрику.*
# - Какие признаки использовали для обучения модели и какая предобработка этих признаков была выполнена?
#
# *Признаки:*
#
# SeniorCitizen - наличие пенсионного статуса
#
# Partner - наличие супруга
#
# Dependents - наличие иждивенцев
#
# Type - тип оплаты услуг (каждый месяц, раз в месяц)
#
# PaperlessBilling	-  электронный чек или бумажный
#
# PaymentMethod - способ оплаты
#
# MonthlyCharges - клиент ежемесячно платит
#
# TotalCharges - всего потрачено на услуги
#
# InternetService - интернет подключение может быть двух типов: через телефонную линию (DSL, от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*)
#
# DeviceProtection - антивирус
#
# OnlineSecurity - блокировка небезопасных сайтов
#
# TechSupport - выделенная линия технической поддержки
#
# OnlineBackup - облачное хранилище файлов для резервного копирования данных
#
# StreamingTV  - стриминговое телевидение
#
# StreamingMovies - каталог фильмов
#
# MultipleLines - возможность вести звонки на параллельных линиях
#
# Эти признаки были разделены на категориланые и числовые. Категориальные были закодированы OneHotEncoder, а числовые были отмасштабированы при помощи Scaler.
#
# - Какая ваша итоговая модель, какие у неё гиперпараметы и какое качество?
#
# Лучшей моделью оказалась CatBoostClassifier с парматерами:
#
# {'mod__n_estimators': 40,
#  'mod__learning_rate': 0.5,
#  'mod__l2_leaf_reg': 1,
#  'mod__depth': 6}

# %% [markdown]
# **Что можно сделать, чтобы уменьшить кол-во уходящий клиентов?**

# %% [markdown]
# Как было выяснено в ходе исследования, метод оплаты и тип оплаты имеют некоторое влияние на лояльность клиента. Выше было показано, что среди оставшихся клиентов превалирует тип оплаты ежемесячный, в то время как среди ушедших все типы оплаты одинаково популярны. Следовательно, желание продолжить пользоваться услугами больше у людей оплачивающих счет каждый меясц, поэтому можно при выборе ежемесячной оплаты предлагать клиентам небольшую дополнительную скидку.
